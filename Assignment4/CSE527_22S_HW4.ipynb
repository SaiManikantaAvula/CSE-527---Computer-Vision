# %% [markdown]
# # CSE527 Homework 4
# **Due date: 11:59 pm EST on April 24, 2022 (Sun.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
# **Do not upload** the data subfolder before submitting on blackboard due to size limit. There should be only one .ipynb file under your root folder Surname_Givenname_SBUID.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time
import gc # changed
import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Set your working directory (in your google drive)
#   change it to your specific homework directory.
# %cd '/content/gdrive/MyDrive/CV/Avula_SaiManikanta_114701486_hw4'
# %cd '/content/gdrive/MyDrive/cv/test/Avula_SaiManikanta_114701486_hw4'
# Out:
# /content/gdrive/.shortcut-targets-by-id/1RtoXUP6U2nsH_SNWH64JQWwcFtbidq6X/Avula_SaiManikanta_114701486_hw4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------


def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)

def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False, augment_rotate =  False):    
    data = []
    labels = []    
    channel_num = 3 if is_color else 1
        
    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)
            
            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
            
            if is_color:
                img = np.transpose(img, [2, 0, 1])
            
            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)
            
    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment: 
        # pass
      data += [cv2.flip(eachImg ,1) for eachImg in data]
      labels += labels


    if augment_rotate:
      
      data += [cv2.rotate(eachImg,cv2.ROTATE_90_COUNTERCLOCKWISE ) for eachImg in data]
      labels += labels

    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
        # pass

        data = [(eachImg - np.mean(eachImg)) for eachImg in data]

        
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 
    
    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Forest', 1: 'Coast', 2: 'Flower', 3: 'Bedroom', 4: 'LivingRoom', 5: 'Kitchen', 6: 'Office', 7: 'Street', 8: 'OpenCountry', 9: 'Mountain', 10: 'Store', 11: 'Highway', 12: 'InsideCity', 13: 'Industrial', 14: 'Suburb', 15: 'TallBuilding'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# TallBuilding

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# Gone are the days of hand designed features. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a simpe network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()
    
  iters = 0
  running_loss = 0.0
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    if testloader is not None and ep % eval_epoch == 0:
      evalModel(net, testloader)

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))        
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_option['device'] = device
trainModel(net, trainloader_small, train_option, testloader_small)

del net
gc.collect()
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7883 | Average Loss: 2.7883
# Epoch: 1 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.5512 | Average Loss: 2.6764
# Accuracy: 0.356771 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.6990 | Average Loss: 2.4497
# Epoch: 2 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.0129 | Average Loss: 2.2529
# Accuracy: 0.424479 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.2755 | Average Loss: 2.1148
# Epoch: 3 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.6448 | Average Loss: 1.9844
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0199 | Average Loss: 1.8805
# Epoch: 4 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.3794 | Average Loss: 1.7786
# Accuracy: 0.455729 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.8368 | Average Loss: 1.6948
# Epoch: 5 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.1768 | Average Loss: 1.6109
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6992 | Average Loss: 1.5418
# Epoch: 6 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.9844 | Average Loss: 1.4710
# Accuracy: 0.473958 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.5901 | Average Loss: 1.4131
# Epoch: 7 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.7746 | Average Loss: 1.3519
# Accuracy: 0.476562 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.5113 | Average Loss: 1.3019
# Epoch: 8 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.5884 | Average Loss: 1.2477
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4304 | Average Loss: 1.2036
# Epoch: 9 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.4768 | Average Loss: 1.1560
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.3599 | Average Loss: 1.1172
# Epoch:10 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.3902 | Average Loss: 1.0756
# Accuracy: 0.489583 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.3267 | Average Loss: 1.0420
# Epoch:11 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.3507 | Average Loss: 1.0055
# Accuracy: 0.489583 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.2884 | Average Loss: 0.9766
# Epoch:12 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.3118 | Average Loss: 0.9441
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.2712 | Average Loss: 0.9193
# Epoch:13 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.2593 | Average Loss: 0.8907
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.2894 | Average Loss: 0.8690
# Epoch:14 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.2407 | Average Loss: 0.8449
# Accuracy: 0.479167 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.2611 | Average Loss: 0.8261
# Epoch:15 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.2805 | Average Loss: 0.8081
# Accuracy: 0.453125 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.4445 | Average Loss: 0.7928
# Epoch:16 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.4380 | Average Loss: 0.7792
# Accuracy: 0.419271 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.5313 | Average Loss: 0.7679
# Epoch:17 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.3063 | Average Loss: 0.7556
# Accuracy: 0.453125 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.4143 | Average Loss: 0.7449
# Epoch:18 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.2678 | Average Loss: 0.7319
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.2307 | Average Loss: 0.7193
# Epoch:19 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.2413 | Average Loss: 0.7049
# Accuracy: 0.473958 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.2078 | Average Loss: 0.6926
# Epoch:20 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.1326 | Average Loss: 0.6784
# Accuracy: 0.489583 | Time: 00:00:00
# 2467

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = nn.Sequential(
        nn.Conv2d(1, 32,  3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4),
        # nn.Conv2d(1, 16,  3),
        # nn.ReLU(),
        # nn.MaxPool2d(4, stride=4),

      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600*2, 16), 
         nn.Dropout(0.5)
      )

      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'gpu'
train_option = {'lr': 0.001, 'epoch': 40,  'device' : device}
trainModel(net, trainloader_small, train_option, testloader_small)

print(net, '1.1 network')
del net
gc.collect()
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:08 | Train Loss: 2.7960 | Average Loss: 2.7960
# Epoch: 1 | Iter:   20 | Time: 00:00:08 | Train Loss: 2.7334 | Average Loss: 3.0180
# Epoch: 1 | Iter:   40 | Time: 00:00:08 | Train Loss: 2.4353 | Average Loss: 2.8294
# Epoch: 1 | Iter:   60 | Time: 00:00:08 | Train Loss: 2.3948 | Average Loss: 2.7033
# Accuracy: 0.377604 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:08 | Train Loss: 2.2864 | Average Loss: 2.6503
# Epoch: 2 | Iter:   20 | Time: 00:00:08 | Train Loss: 2.2261 | Average Loss: 2.5871
# Epoch: 2 | Iter:   40 | Time: 00:00:09 | Train Loss: 2.2387 | Average Loss: 2.5563
# Epoch: 2 | Iter:   60 | Time: 00:00:09 | Train Loss: 2.2939 | Average Loss: 2.5090
# Accuracy: 0.442708 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:09 | Train Loss: 2.0538 | Average Loss: 2.4813
# Epoch: 3 | Iter:   20 | Time: 00:00:09 | Train Loss: 2.1523 | Average Loss: 2.4441
# Epoch: 3 | Iter:   40 | Time: 00:00:09 | Train Loss: 2.0804 | Average Loss: 2.4150
# Epoch: 3 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.9762 | Average Loss: 2.3779
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.6932 | Average Loss: 2.3556
# Epoch: 4 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.8611 | Average Loss: 2.3251
# Epoch: 4 | Iter:   40 | Time: 00:00:10 | Train Loss: 2.0266 | Average Loss: 2.3019
# Epoch: 4 | Iter:   60 | Time: 00:00:10 | Train Loss: 2.1948 | Average Loss: 2.2785
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.9138 | Average Loss: 2.2585
# Epoch: 5 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.8495 | Average Loss: 2.2349
# Epoch: 5 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.9142 | Average Loss: 2.2144
# Epoch: 5 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.9250 | Average Loss: 2.1938
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.8931 | Average Loss: 2.1812
# Epoch: 6 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.7684 | Average Loss: 2.1635
# Epoch: 6 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.7740 | Average Loss: 2.1486
# Epoch: 6 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.7271 | Average Loss: 2.1327
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.7232 | Average Loss: 2.1192
# Epoch: 7 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.7171 | Average Loss: 2.1031
# Epoch: 7 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.7992 | Average Loss: 2.0900
# Epoch: 7 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.6462 | Average Loss: 2.0764
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.8028 | Average Loss: 2.0674
# Epoch: 8 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.8963 | Average Loss: 2.0547
# Epoch: 8 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.7066 | Average Loss: 2.0441
# Epoch: 8 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.7692 | Average Loss: 2.0317
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.9652 | Average Loss: 2.0243
# Epoch: 9 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.6555 | Average Loss: 2.0116
# Epoch: 9 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.5703 | Average Loss: 2.0005
# Epoch: 9 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.5929 | Average Loss: 1.9881
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.8344 | Average Loss: 1.9795
# Epoch:10 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.5773 | Average Loss: 1.9680
# Epoch:10 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.6686 | Average Loss: 1.9595
# Epoch:10 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.6691 | Average Loss: 1.9490
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.3866 | Average Loss: 1.9407
# Epoch:11 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.6221 | Average Loss: 1.9312
# Epoch:11 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.5485 | Average Loss: 1.9228
# Epoch:11 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.6643 | Average Loss: 1.9144
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.5463 | Average Loss: 1.9071
# Epoch:12 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.6720 | Average Loss: 1.8990
# Epoch:12 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.4165 | Average Loss: 1.8915
# Epoch:12 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.7896 | Average Loss: 1.8832
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.3814 | Average Loss: 1.8761
# Epoch:13 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.3394 | Average Loss: 1.8679
# Epoch:13 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.5164 | Average Loss: 1.8584
# Epoch:13 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.5941 | Average Loss: 1.8502
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.3723 | Average Loss: 1.8439
# Epoch:14 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.7509 | Average Loss: 1.8365
# Epoch:14 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.5156 | Average Loss: 1.8297
# Epoch:14 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.4064 | Average Loss: 1.8217
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.5762 | Average Loss: 1.8171
# Epoch:15 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.3739 | Average Loss: 1.8105
# Epoch:15 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.4179 | Average Loss: 1.8037
# Epoch:15 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.4055 | Average Loss: 1.7977
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.3477 | Average Loss: 1.7928
# Epoch:16 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.4101 | Average Loss: 1.7869
# Epoch:16 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.3892 | Average Loss: 1.7809
# Epoch:16 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.3625 | Average Loss: 1.7738
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.4013 | Average Loss: 1.7686
# Epoch:17 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.2399 | Average Loss: 1.7626
# Epoch:17 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.4590 | Average Loss: 1.7573
# Epoch:17 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.5204 | Average Loss: 1.7512
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.2703 | Average Loss: 1.7467
# Epoch:18 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.5329 | Average Loss: 1.7411
# Epoch:18 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.3149 | Average Loss: 1.7351
# Epoch:18 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.4827 | Average Loss: 1.7293
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.6237 | Average Loss: 1.7252
# Epoch:19 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.2205 | Average Loss: 1.7200
# Epoch:19 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.3115 | Average Loss: 1.7159
# Epoch:19 | Iter:   60 | Time: 00:00:17 | Train Loss: 1.4258 | Average Loss: 1.7107
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.4089 | Average Loss: 1.7071
# Epoch:20 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.2996 | Average Loss: 1.7024
# Epoch:20 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.4539 | Average Loss: 1.6982
# Epoch:20 | Iter:   60 | Time: 00:00:17 | Train Loss: 1.2853 | Average Loss: 1.6935
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.2615 | Average Loss: 1.6899
# Epoch:21 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.3365 | Average Loss: 1.6851
# Epoch:21 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.4754 | Average Loss: 1.6804
# Epoch:21 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.2434 | Average Loss: 1.6756
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.0932 | Average Loss: 1.6715
# Epoch:22 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.4791 | Average Loss: 1.6668
# Epoch:22 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.4300 | Average Loss: 1.6624
# Epoch:22 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.3243 | Average Loss: 1.6576
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.1967 | Average Loss: 1.6542
# Epoch:23 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.2796 | Average Loss: 1.6495
# Epoch:23 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.9018 | Average Loss: 1.6452
# Epoch:23 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.2295 | Average Loss: 1.6412
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.0846 | Average Loss: 1.6382
# Epoch:24 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.2842 | Average Loss: 1.6341
# Epoch:24 | Iter:   40 | Time: 00:00:19 | Train Loss: 1.3077 | Average Loss: 1.6302
# Epoch:24 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.3978 | Average Loss: 1.6265
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.0833 | Average Loss: 1.6231
# Epoch:25 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.1910 | Average Loss: 1.6192
# Epoch:25 | Iter:   40 | Time: 00:00:19 | Train Loss: 1.1152 | Average Loss: 1.6151
# Epoch:25 | Iter:   60 | Time: 00:00:20 | Train Loss: 1.4683 | Average Loss: 1.6120
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:20 | Train Loss: 1.0755 | Average Loss: 1.6095
# Epoch:26 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.3658 | Average Loss: 1.6051
# Epoch:26 | Iter:   40 | Time: 00:00:20 | Train Loss: 1.1524 | Average Loss: 1.6018
# Epoch:26 | Iter:   60 | Time: 00:00:20 | Train Loss: 1.3915 | Average Loss: 1.5991
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:20 | Train Loss: 1.3531 | Average Loss: 1.5965
# Epoch:27 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.1831 | Average Loss: 1.5935
# Epoch:27 | Iter:   40 | Time: 00:00:20 | Train Loss: 1.0383 | Average Loss: 1.5903
# Epoch:27 | Iter:   60 | Time: 00:00:20 | Train Loss: 1.5900 | Average Loss: 1.5877
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:21 | Train Loss: 1.1126 | Average Loss: 1.5855
# Epoch:28 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.1412 | Average Loss: 1.5827
# Epoch:28 | Iter:   40 | Time: 00:00:21 | Train Loss: 1.2136 | Average Loss: 1.5793
# Epoch:28 | Iter:   60 | Time: 00:00:21 | Train Loss: 1.1679 | Average Loss: 1.5763
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:21 | Train Loss: 1.1314 | Average Loss: 1.5736
# Epoch:29 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.1500 | Average Loss: 1.5705
# Epoch:29 | Iter:   40 | Time: 00:00:21 | Train Loss: 1.2998 | Average Loss: 1.5680
# Epoch:29 | Iter:   60 | Time: 00:00:21 | Train Loss: 1.1989 | Average Loss: 1.5647
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.1088 | Average Loss: 1.5624
# Epoch:30 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.2309 | Average Loss: 1.5595
# Epoch:30 | Iter:   40 | Time: 00:00:22 | Train Loss: 1.3594 | Average Loss: 1.5567
# Epoch:30 | Iter:   60 | Time: 00:00:22 | Train Loss: 1.0769 | Average Loss: 1.5538
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.3553 | Average Loss: 1.5520
# Epoch:31 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.1217 | Average Loss: 1.5490
# Epoch:31 | Iter:   40 | Time: 00:00:22 | Train Loss: 1.3006 | Average Loss: 1.5466
# Epoch:31 | Iter:   60 | Time: 00:00:22 | Train Loss: 1.3321 | Average Loss: 1.5436
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.1860 | Average Loss: 1.5414
# Epoch:32 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.0983 | Average Loss: 1.5386
# Epoch:32 | Iter:   40 | Time: 00:00:23 | Train Loss: 1.3055 | Average Loss: 1.5365
# Epoch:32 | Iter:   60 | Time: 00:00:23 | Train Loss: 1.1540 | Average Loss: 1.5335
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:23 | Train Loss: 1.2233 | Average Loss: 1.5314
# Epoch:33 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.0799 | Average Loss: 1.5288
# Epoch:33 | Iter:   40 | Time: 00:00:23 | Train Loss: 1.1252 | Average Loss: 1.5263
# Epoch:33 | Iter:   60 | Time: 00:00:23 | Train Loss: 1.1172 | Average Loss: 1.5238
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:23 | Train Loss: 1.0870 | Average Loss: 1.5219
# Epoch:34 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.1182 | Average Loss: 1.5195
# Epoch:34 | Iter:   40 | Time: 00:00:24 | Train Loss: 1.1047 | Average Loss: 1.5167
# Epoch:34 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.8657 | Average Loss: 1.5143
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.8935 | Average Loss: 1.5125
# Epoch:35 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.1269 | Average Loss: 1.5099
# Epoch:35 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.9182 | Average Loss: 1.5074
# Epoch:35 | Iter:   60 | Time: 00:00:24 | Train Loss: 1.4026 | Average Loss: 1.5057
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:24 | Train Loss: 1.1326 | Average Loss: 1.5037
# Epoch:36 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.0631 | Average Loss: 1.5013
# Epoch:36 | Iter:   40 | Time: 00:00:25 | Train Loss: 1.0747 | Average Loss: 1.4990
# Epoch:36 | Iter:   60 | Time: 00:00:25 | Train Loss: 1.0217 | Average Loss: 1.4963
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:25 | Train Loss: 1.1617 | Average Loss: 1.4946
# Epoch:37 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.1326 | Average Loss: 1.4921
# Epoch:37 | Iter:   40 | Time: 00:00:25 | Train Loss: 1.1754 | Average Loss: 1.4901
# Epoch:37 | Iter:   60 | Time: 00:00:25 | Train Loss: 1.1401 | Average Loss: 1.4881
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:25 | Train Loss: 1.4600 | Average Loss: 1.4867
# Epoch:38 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.2585 | Average Loss: 1.4840
# Epoch:38 | Iter:   40 | Time: 00:00:26 | Train Loss: 1.3830 | Average Loss: 1.4819
# Epoch:38 | Iter:   60 | Time: 00:00:26 | Train Loss: 1.1154 | Average Loss: 1.4800
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:26 | Train Loss: 1.1664 | Average Loss: 1.4785
# Epoch:39 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.1960 | Average Loss: 1.4764
# Epoch:39 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.9895 | Average Loss: 1.4739
# Epoch:39 | Iter:   60 | Time: 00:00:26 | Train Loss: 1.2203 | Average Loss: 1.4720
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.9857 | Average Loss: 1.4703
# Epoch:40 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.0331 | Average Loss: 1.4681
# Epoch:40 | Iter:   40 | Time: 00:00:26 | Train Loss: 1.1847 | Average Loss: 1.4662
# Epoch:40 | Iter:   60 | Time: 00:00:27 | Train Loss: 1.0702 | Average Loss: 1.4645
# Accuracy: 0.575521 | Time: 00:00:00
# TNet(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=7200, out_features=16, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#   )
# ) 1.1 network
# 108

# %% [markdown]
# **Answer**:
#
# Data augmentation:  Every image is flipped around y-axis and augmented them to the dataset (Problem 0)
#
# Data normalization: Every image is now zero-centered as I have subtracted mean of an images from the all the pixels in an individual image (Problem 0)
#
# Layer 1: 32 Convolution filters of shape 3*3, stride 1 by default
#
# Layer 2:  ReLU Activation
#
# Layer 3: Max Pooling of shape 4*4 with stride 4
#
# Layer 4: Added a drop rate p = 0.5 (default)
#
# Layer 5: A fully connected dense layer which has 3600*2 nodes as input and 16 nodes as output
#
# ...
#
# Accuray on test set:  *57.5521 %* (Best - at 34th epoch)

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        # Layer 1
        nn.Conv2d(1, 32,  3),
        nn.ReLU(),
        #nn.Sigmoid()
        #nn.Tanh()
        nn.MaxPool2d(3, stride=3),


        # Layer 2
        nn.Conv2d(32, 16, 3), 
        nn.ReLU(),
        #nn.Sigmoid()
        #nn.Tanh()
        nn.MaxPool2d(3, stride=3),
        nn.Dropout(0.5)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(576, 212), 
         nn.Dropout(0.5),
         nn.Linear(212, 16) 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'gpu'
train_option = {'lr': 0.0005, 'epoch': 50,  'device' : device }
trainModel(net, trainloader_small, train_option, testloader_small)

print(net, '1.2 - (a) network')
del net
gc.collect()
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9123 | Average Loss: 2.9123
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6430 | Average Loss: 2.7701
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5578 | Average Loss: 2.6910
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.4116 | Average Loss: 2.6348
# Epoch: 1 | Iter:   80 | Time: 00:00:00 | Train Loss: 2.3983 | Average Loss: 2.5872
# Epoch: 1 | Iter:  100 | Time: 00:00:00 | Train Loss: 2.2489 | Average Loss: 2.5439
# Epoch: 1 | Iter:  120 | Time: 00:00:00 | Train Loss: 2.2904 | Average Loss: 2.5096
# Epoch: 1 | Iter:  140 | Time: 00:00:00 | Train Loss: 2.4857 | Average Loss: 2.4792
# Accuracy: 0.359375 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.1471 | Average Loss: 2.4654
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.1621 | Average Loss: 2.4337
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.1379 | Average Loss: 2.4080
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.0229 | Average Loss: 2.3792
# Epoch: 2 | Iter:   80 | Time: 00:00:01 | Train Loss: 2.0778 | Average Loss: 2.3516
# Epoch: 2 | Iter:  100 | Time: 00:00:01 | Train Loss: 1.8889 | Average Loss: 2.3267
# Epoch: 2 | Iter:  120 | Time: 00:00:01 | Train Loss: 2.1142 | Average Loss: 2.3029
# Epoch: 2 | Iter:  140 | Time: 00:00:01 | Train Loss: 2.1421 | Average Loss: 2.2777
# Accuracy: 0.455729 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8334 | Average Loss: 2.2658
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.8957 | Average Loss: 2.2406
# Epoch: 3 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.8429 | Average Loss: 2.2179
# Epoch: 3 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.7101 | Average Loss: 2.1949
# Epoch: 3 | Iter:   80 | Time: 00:00:02 | Train Loss: 1.7526 | Average Loss: 2.1731
# Epoch: 3 | Iter:  100 | Time: 00:00:02 | Train Loss: 1.6972 | Average Loss: 2.1524
# Epoch: 3 | Iter:  120 | Time: 00:00:02 | Train Loss: 1.8938 | Average Loss: 2.1333
# Epoch: 3 | Iter:  140 | Time: 00:00:02 | Train Loss: 1.8499 | Average Loss: 2.1132
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.6670 | Average Loss: 2.1037
# Epoch: 4 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.7653 | Average Loss: 2.0839
# Epoch: 4 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.6415 | Average Loss: 2.0670
# Epoch: 4 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.5505 | Average Loss: 2.0494
# Epoch: 4 | Iter:   80 | Time: 00:00:03 | Train Loss: 1.5869 | Average Loss: 2.0336
# Epoch: 4 | Iter:  100 | Time: 00:00:03 | Train Loss: 1.6771 | Average Loss: 2.0182
# Epoch: 4 | Iter:  120 | Time: 00:00:03 | Train Loss: 1.5901 | Average Loss: 2.0033
# Epoch: 4 | Iter:  140 | Time: 00:00:03 | Train Loss: 1.8778 | Average Loss: 1.9875
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5361 | Average Loss: 1.9799
# Epoch: 5 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.6892 | Average Loss: 1.9657
# Epoch: 5 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.4449 | Average Loss: 1.9520
# Epoch: 5 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.3327 | Average Loss: 1.9380
# Epoch: 5 | Iter:   80 | Time: 00:00:04 | Train Loss: 1.5497 | Average Loss: 1.9260
# Epoch: 5 | Iter:  100 | Time: 00:00:04 | Train Loss: 1.5952 | Average Loss: 1.9146
# Epoch: 5 | Iter:  120 | Time: 00:00:04 | Train Loss: 1.5239 | Average Loss: 1.9033
# Epoch: 5 | Iter:  140 | Time: 00:00:04 | Train Loss: 1.6884 | Average Loss: 1.8919
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.4793 | Average Loss: 1.8867
# Epoch: 6 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.5336 | Average Loss: 1.8748
# Epoch: 6 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.4218 | Average Loss: 1.8643
# Epoch: 6 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.3020 | Average Loss: 1.8540
# Epoch: 6 | Iter:   80 | Time: 00:00:04 | Train Loss: 1.5085 | Average Loss: 1.8450
# Epoch: 6 | Iter:  100 | Time: 00:00:05 | Train Loss: 1.6320 | Average Loss: 1.8358
# Epoch: 6 | Iter:  120 | Time: 00:00:05 | Train Loss: 1.4599 | Average Loss: 1.8268
# Epoch: 6 | Iter:  140 | Time: 00:00:05 | Train Loss: 1.6360 | Average Loss: 1.8177
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.3999 | Average Loss: 1.8129
# Epoch: 7 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.5718 | Average Loss: 1.8040
# Epoch: 7 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.3287 | Average Loss: 1.7961
# Epoch: 7 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.1842 | Average Loss: 1.7878
# Epoch: 7 | Iter:   80 | Time: 00:00:05 | Train Loss: 1.4618 | Average Loss: 1.7802
# Epoch: 7 | Iter:  100 | Time: 00:00:05 | Train Loss: 1.5341 | Average Loss: 1.7722
# Epoch: 7 | Iter:  120 | Time: 00:00:06 | Train Loss: 1.3573 | Average Loss: 1.7643
# Epoch: 7 | Iter:  140 | Time: 00:00:06 | Train Loss: 1.6030 | Average Loss: 1.7569
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.3741 | Average Loss: 1.7531
# Epoch: 8 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.6415 | Average Loss: 1.7454
# Epoch: 8 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.2428 | Average Loss: 1.7384
# Epoch: 8 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.1399 | Average Loss: 1.7310
# Epoch: 8 | Iter:   80 | Time: 00:00:06 | Train Loss: 1.4290 | Average Loss: 1.7240
# Epoch: 8 | Iter:  100 | Time: 00:00:06 | Train Loss: 1.5008 | Average Loss: 1.7175
# Epoch: 8 | Iter:  120 | Time: 00:00:06 | Train Loss: 1.4742 | Average Loss: 1.7112
# Epoch: 8 | Iter:  140 | Time: 00:00:07 | Train Loss: 1.3533 | Average Loss: 1.7047
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.3065 | Average Loss: 1.7014
# Epoch: 9 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.4618 | Average Loss: 1.6950
# Epoch: 9 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.3051 | Average Loss: 1.6887
# Epoch: 9 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.2514 | Average Loss: 1.6824
# Epoch: 9 | Iter:   80 | Time: 00:00:07 | Train Loss: 1.3726 | Average Loss: 1.6767
# Epoch: 9 | Iter:  100 | Time: 00:00:07 | Train Loss: 1.5656 | Average Loss: 1.6717
# Epoch: 9 | Iter:  120 | Time: 00:00:07 | Train Loss: 1.3473 | Average Loss: 1.6664
# Epoch: 9 | Iter:  140 | Time: 00:00:07 | Train Loss: 1.5570 | Average Loss: 1.6607
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.3073 | Average Loss: 1.6580
# Epoch:10 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.3580 | Average Loss: 1.6522
# Epoch:10 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.1191 | Average Loss: 1.6469
# Epoch:10 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.1690 | Average Loss: 1.6414
# Epoch:10 | Iter:   80 | Time: 00:00:08 | Train Loss: 1.2193 | Average Loss: 1.6363
# Epoch:10 | Iter:  100 | Time: 00:00:08 | Train Loss: 1.4427 | Average Loss: 1.6313
# Epoch:10 | Iter:  120 | Time: 00:00:08 | Train Loss: 1.3136 | Average Loss: 1.6266
# Epoch:10 | Iter:  140 | Time: 00:00:08 | Train Loss: 1.3893 | Average Loss: 1.6216
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.1253 | Average Loss: 1.6189
# Epoch:11 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.4910 | Average Loss: 1.6140
# Epoch:11 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.2312 | Average Loss: 1.6097
# Epoch:11 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.1501 | Average Loss: 1.6050
# Epoch:11 | Iter:   80 | Time: 00:00:09 | Train Loss: 1.2019 | Average Loss: 1.6008
# Epoch:11 | Iter:  100 | Time: 00:00:09 | Train Loss: 1.3413 | Average Loss: 1.5967
# Epoch:11 | Iter:  120 | Time: 00:00:09 | Train Loss: 1.3146 | Average Loss: 1.5927
# Epoch:11 | Iter:  140 | Time: 00:00:09 | Train Loss: 1.3921 | Average Loss: 1.5883
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.1685 | Average Loss: 1.5861
# Epoch:12 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.4532 | Average Loss: 1.5819
# Epoch:12 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.2015 | Average Loss: 1.5780
# Epoch:12 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.1298 | Average Loss: 1.5739
# Epoch:12 | Iter:   80 | Time: 00:00:10 | Train Loss: 1.1237 | Average Loss: 1.5698
# Epoch:12 | Iter:  100 | Time: 00:00:10 | Train Loss: 1.3863 | Average Loss: 1.5661
# Epoch:12 | Iter:  120 | Time: 00:00:10 | Train Loss: 1.2872 | Average Loss: 1.5624
# Epoch:12 | Iter:  140 | Time: 00:00:10 | Train Loss: 1.4185 | Average Loss: 1.5585
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.2854 | Average Loss: 1.5568
# Epoch:13 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.2916 | Average Loss: 1.5531
# Epoch:13 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.2695 | Average Loss: 1.5495
# Epoch:13 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.1711 | Average Loss: 1.5458
# Epoch:13 | Iter:   80 | Time: 00:00:11 | Train Loss: 1.0576 | Average Loss: 1.5424
# Epoch:13 | Iter:  100 | Time: 00:00:11 | Train Loss: 1.3991 | Average Loss: 1.5389
# Epoch:13 | Iter:  120 | Time: 00:00:11 | Train Loss: 1.2714 | Average Loss: 1.5356
# Epoch:13 | Iter:  140 | Time: 00:00:11 | Train Loss: 1.3881 | Average Loss: 1.5322
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.0820 | Average Loss: 1.5304
# Epoch:14 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.4515 | Average Loss: 1.5271
# Epoch:14 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.0143 | Average Loss: 1.5237
# Epoch:14 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.9841 | Average Loss: 1.5200
# Epoch:14 | Iter:   80 | Time: 00:00:12 | Train Loss: 1.0991 | Average Loss: 1.5170
# Epoch:14 | Iter:  100 | Time: 00:00:12 | Train Loss: 1.3531 | Average Loss: 1.5138
# Epoch:14 | Iter:  120 | Time: 00:00:12 | Train Loss: 1.1184 | Average Loss: 1.5106
# Epoch:14 | Iter:  140 | Time: 00:00:12 | Train Loss: 1.3534 | Average Loss: 1.5073
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.1243 | Average Loss: 1.5056
# Epoch:15 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.2661 | Average Loss: 1.5025
# Epoch:15 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.0797 | Average Loss: 1.4992
# Epoch:15 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.1154 | Average Loss: 1.4963
# Epoch:15 | Iter:   80 | Time: 00:00:12 | Train Loss: 1.2833 | Average Loss: 1.4936
# Epoch:15 | Iter:  100 | Time: 00:00:13 | Train Loss: 1.3404 | Average Loss: 1.4910
# Epoch:15 | Iter:  120 | Time: 00:00:13 | Train Loss: 1.3403 | Average Loss: 1.4881
# Epoch:15 | Iter:  140 | Time: 00:00:13 | Train Loss: 1.1959 | Average Loss: 1.4851
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.0922 | Average Loss: 1.4837
# Epoch:16 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.3140 | Average Loss: 1.4809
# Epoch:16 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.1398 | Average Loss: 1.4781
# Epoch:16 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.0229 | Average Loss: 1.4753
# Epoch:16 | Iter:   80 | Time: 00:00:13 | Train Loss: 1.0898 | Average Loss: 1.4726
# Epoch:16 | Iter:  100 | Time: 00:00:13 | Train Loss: 1.3611 | Average Loss: 1.4700
# Epoch:16 | Iter:  120 | Time: 00:00:14 | Train Loss: 1.2961 | Average Loss: 1.4674
# Epoch:16 | Iter:  140 | Time: 00:00:14 | Train Loss: 1.4387 | Average Loss: 1.4648
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.2142 | Average Loss: 1.4634
# Epoch:17 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.4192 | Average Loss: 1.4611
# Epoch:17 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.0765 | Average Loss: 1.4584
# Epoch:17 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.9030 | Average Loss: 1.4557
# Epoch:17 | Iter:   80 | Time: 00:00:14 | Train Loss: 1.1901 | Average Loss: 1.4533
# Epoch:17 | Iter:  100 | Time: 00:00:14 | Train Loss: 1.4842 | Average Loss: 1.4509
# Epoch:17 | Iter:  120 | Time: 00:00:14 | Train Loss: 1.0762 | Average Loss: 1.4487
# Epoch:17 | Iter:  140 | Time: 00:00:15 | Train Loss: 1.4329 | Average Loss: 1.4464
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.1448 | Average Loss: 1.4452
# Epoch:18 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.0988 | Average Loss: 1.4429
# Epoch:18 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.1004 | Average Loss: 1.4403
# Epoch:18 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.8878 | Average Loss: 1.4376
# Epoch:18 | Iter:   80 | Time: 00:00:15 | Train Loss: 1.1311 | Average Loss: 1.4355
# Epoch:18 | Iter:  100 | Time: 00:00:15 | Train Loss: 1.2697 | Average Loss: 1.4334
# Epoch:18 | Iter:  120 | Time: 00:00:15 | Train Loss: 1.1241 | Average Loss: 1.4311
# Epoch:18 | Iter:  140 | Time: 00:00:15 | Train Loss: 1.3758 | Average Loss: 1.4288
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.2483 | Average Loss: 1.4276
# Epoch:19 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.3836 | Average Loss: 1.4255
# Epoch:19 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.0541 | Average Loss: 1.4231
# Epoch:19 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.1330 | Average Loss: 1.4207
# Epoch:19 | Iter:   80 | Time: 00:00:16 | Train Loss: 1.2095 | Average Loss: 1.4187
# Epoch:19 | Iter:  100 | Time: 00:00:16 | Train Loss: 1.2776 | Average Loss: 1.4167
# Epoch:19 | Iter:  120 | Time: 00:00:16 | Train Loss: 1.2038 | Average Loss: 1.4145
# Epoch:19 | Iter:  140 | Time: 00:00:16 | Train Loss: 1.1864 | Average Loss: 1.4122
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.0097 | Average Loss: 1.4110
# Epoch:20 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.2537 | Average Loss: 1.4089
# Epoch:20 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.9008 | Average Loss: 1.4067
# Epoch:20 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.9070 | Average Loss: 1.4044
# Epoch:20 | Iter:   80 | Time: 00:00:17 | Train Loss: 1.0333 | Average Loss: 1.4024
# Epoch:20 | Iter:  100 | Time: 00:00:17 | Train Loss: 1.3203 | Average Loss: 1.4005
# Epoch:20 | Iter:  120 | Time: 00:00:17 | Train Loss: 1.1912 | Average Loss: 1.3986
# Epoch:20 | Iter:  140 | Time: 00:00:17 | Train Loss: 1.2430 | Average Loss: 1.3964
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.0611 | Average Loss: 1.3954
# Epoch:21 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.1987 | Average Loss: 1.3934
# Epoch:21 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.9219 | Average Loss: 1.3913
# Epoch:21 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.9565 | Average Loss: 1.3893
# Epoch:21 | Iter:   80 | Time: 00:00:18 | Train Loss: 0.9268 | Average Loss: 1.3873
# Epoch:21 | Iter:  100 | Time: 00:00:18 | Train Loss: 1.2845 | Average Loss: 1.3856
# Epoch:21 | Iter:  120 | Time: 00:00:18 | Train Loss: 1.0317 | Average Loss: 1.3837
# Epoch:21 | Iter:  140 | Time: 00:00:18 | Train Loss: 1.4141 | Average Loss: 1.3820
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.0486 | Average Loss: 1.3810
# Epoch:22 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.2819 | Average Loss: 1.3791
# Epoch:22 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.8694 | Average Loss: 1.3773
# Epoch:22 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.7943 | Average Loss: 1.3753
# Epoch:22 | Iter:   80 | Time: 00:00:19 | Train Loss: 1.0546 | Average Loss: 1.3733
# Epoch:22 | Iter:  100 | Time: 00:00:19 | Train Loss: 1.1184 | Average Loss: 1.3715
# Epoch:22 | Iter:  120 | Time: 00:00:19 | Train Loss: 1.2385 | Average Loss: 1.3700
# Epoch:22 | Iter:  140 | Time: 00:00:19 | Train Loss: 1.4027 | Average Loss: 1.3681
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.0510 | Average Loss: 1.3671
# Epoch:23 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.3089 | Average Loss: 1.3653
# Epoch:23 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.9745 | Average Loss: 1.3636
# Epoch:23 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.0291 | Average Loss: 1.3620
# Epoch:23 | Iter:   80 | Time: 00:00:19 | Train Loss: 0.9668 | Average Loss: 1.3603
# Epoch:23 | Iter:  100 | Time: 00:00:20 | Train Loss: 1.3840 | Average Loss: 1.3589
# Epoch:23 | Iter:  120 | Time: 00:00:20 | Train Loss: 1.0355 | Average Loss: 1.3574
# Epoch:23 | Iter:  140 | Time: 00:00:20 | Train Loss: 1.2783 | Average Loss: 1.3558
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.8560 | Average Loss: 1.3549
# Epoch:24 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.1019 | Average Loss: 1.3531
# Epoch:24 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.9474 | Average Loss: 1.3515
# Epoch:24 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.9735 | Average Loss: 1.3497
# Epoch:24 | Iter:   80 | Time: 00:00:20 | Train Loss: 1.2037 | Average Loss: 1.3480
# Epoch:24 | Iter:  100 | Time: 00:00:20 | Train Loss: 1.2274 | Average Loss: 1.3465
# Epoch:24 | Iter:  120 | Time: 00:00:21 | Train Loss: 1.1670 | Average Loss: 1.3451
# Epoch:24 | Iter:  140 | Time: 00:00:21 | Train Loss: 1.3178 | Average Loss: 1.3436
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:21 | Train Loss: 1.0463 | Average Loss: 1.3427
# Epoch:25 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.1743 | Average Loss: 1.3409
# Epoch:25 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.8309 | Average Loss: 1.3392
# Epoch:25 | Iter:   60 | Time: 00:00:21 | Train Loss: 1.0063 | Average Loss: 1.3378
# Epoch:25 | Iter:   80 | Time: 00:00:21 | Train Loss: 1.0611 | Average Loss: 1.3363
# Epoch:25 | Iter:  100 | Time: 00:00:21 | Train Loss: 1.2390 | Average Loss: 1.3349
# Epoch:25 | Iter:  120 | Time: 00:00:21 | Train Loss: 1.0835 | Average Loss: 1.3335
# Epoch:25 | Iter:  140 | Time: 00:00:22 | Train Loss: 1.2845 | Average Loss: 1.3319
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.8873 | Average Loss: 1.3310
# Epoch:26 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.2006 | Average Loss: 1.3295
# Epoch:26 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.8298 | Average Loss: 1.3280
# Epoch:26 | Iter:   60 | Time: 00:00:22 | Train Loss: 0.9945 | Average Loss: 1.3264
# Epoch:26 | Iter:   80 | Time: 00:00:22 | Train Loss: 1.0870 | Average Loss: 1.3248
# Epoch:26 | Iter:  100 | Time: 00:00:22 | Train Loss: 1.1625 | Average Loss: 1.3234
# Epoch:26 | Iter:  120 | Time: 00:00:22 | Train Loss: 0.8886 | Average Loss: 1.3220
# Epoch:26 | Iter:  140 | Time: 00:00:22 | Train Loss: 1.3013 | Average Loss: 1.3205
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.1035 | Average Loss: 1.3197
# Epoch:27 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.0707 | Average Loss: 1.3182
# Epoch:27 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.9924 | Average Loss: 1.3169
# Epoch:27 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.8888 | Average Loss: 1.3155
# Epoch:27 | Iter:   80 | Time: 00:00:23 | Train Loss: 1.0573 | Average Loss: 1.3138
# Epoch:27 | Iter:  100 | Time: 00:00:23 | Train Loss: 1.2481 | Average Loss: 1.3124
# Epoch:27 | Iter:  120 | Time: 00:00:23 | Train Loss: 1.0724 | Average Loss: 1.3110
# Epoch:27 | Iter:  140 | Time: 00:00:23 | Train Loss: 1.3966 | Average Loss: 1.3097
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.9581 | Average Loss: 1.3091
# Epoch:28 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.1522 | Average Loss: 1.3076
# Epoch:28 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.8714 | Average Loss: 1.3062
# Epoch:28 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.8813 | Average Loss: 1.3048
# Epoch:28 | Iter:   80 | Time: 00:00:24 | Train Loss: 0.9161 | Average Loss: 1.3033
# Epoch:28 | Iter:  100 | Time: 00:00:24 | Train Loss: 1.3579 | Average Loss: 1.3022
# Epoch:28 | Iter:  120 | Time: 00:00:24 | Train Loss: 0.9140 | Average Loss: 1.3010
# Epoch:28 | Iter:  140 | Time: 00:00:24 | Train Loss: 1.1282 | Average Loss: 1.2995
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.9374 | Average Loss: 1.2988
# Epoch:29 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.1635 | Average Loss: 1.2974
# Epoch:29 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.8557 | Average Loss: 1.2960
# Epoch:29 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.7896 | Average Loss: 1.2946
# Epoch:29 | Iter:   80 | Time: 00:00:25 | Train Loss: 0.9435 | Average Loss: 1.2931
# Epoch:29 | Iter:  100 | Time: 00:00:25 | Train Loss: 1.3007 | Average Loss: 1.2920
# Epoch:29 | Iter:  120 | Time: 00:00:25 | Train Loss: 1.1670 | Average Loss: 1.2907
# Epoch:29 | Iter:  140 | Time: 00:00:25 | Train Loss: 1.2510 | Average Loss: 1.2894
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:25 | Train Loss: 1.0713 | Average Loss: 1.2887
# Epoch:30 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.2467 | Average Loss: 1.2877
# Epoch:30 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.9764 | Average Loss: 1.2865
# Epoch:30 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.7443 | Average Loss: 1.2851
# Epoch:30 | Iter:   80 | Time: 00:00:26 | Train Loss: 0.9467 | Average Loss: 1.2839
# Epoch:30 | Iter:  100 | Time: 00:00:26 | Train Loss: 1.3786 | Average Loss: 1.2828
# Epoch:30 | Iter:  120 | Time: 00:00:26 | Train Loss: 1.0627 | Average Loss: 1.2814
# Epoch:30 | Iter:  140 | Time: 00:00:26 | Train Loss: 1.2748 | Average Loss: 1.2803
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.9409 | Average Loss: 1.2797
# Epoch:31 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.2143 | Average Loss: 1.2785
# Epoch:31 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.9184 | Average Loss: 1.2772
# Epoch:31 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.9376 | Average Loss: 1.2759
# Epoch:31 | Iter:   80 | Time: 00:00:26 | Train Loss: 1.0608 | Average Loss: 1.2748
# Epoch:31 | Iter:  100 | Time: 00:00:27 | Train Loss: 1.1248 | Average Loss: 1.2736
# Epoch:31 | Iter:  120 | Time: 00:00:27 | Train Loss: 1.1848 | Average Loss: 1.2725
# Epoch:31 | Iter:  140 | Time: 00:00:27 | Train Loss: 1.1813 | Average Loss: 1.2712
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.8636 | Average Loss: 1.2705
# Epoch:32 | Iter:   20 | Time: 00:00:27 | Train Loss: 1.2119 | Average Loss: 1.2693
# Epoch:32 | Iter:   40 | Time: 00:00:27 | Train Loss: 1.0165 | Average Loss: 1.2681
# Epoch:32 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.9186 | Average Loss: 1.2670
# Epoch:32 | Iter:   80 | Time: 00:00:27 | Train Loss: 1.0290 | Average Loss: 1.2658
# Epoch:32 | Iter:  100 | Time: 00:00:27 | Train Loss: 0.9298 | Average Loss: 1.2646
# Epoch:32 | Iter:  120 | Time: 00:00:28 | Train Loss: 1.0800 | Average Loss: 1.2636
# Epoch:32 | Iter:  140 | Time: 00:00:28 | Train Loss: 1.0136 | Average Loss: 1.2623
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.8248 | Average Loss: 1.2617
# Epoch:33 | Iter:   20 | Time: 00:00:28 | Train Loss: 1.0676 | Average Loss: 1.2606
# Epoch:33 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.9374 | Average Loss: 1.2595
# Epoch:33 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.8422 | Average Loss: 1.2584
# Epoch:33 | Iter:   80 | Time: 00:00:28 | Train Loss: 0.9830 | Average Loss: 1.2571
# Epoch:33 | Iter:  100 | Time: 00:00:28 | Train Loss: 1.5502 | Average Loss: 1.2562
# Epoch:33 | Iter:  120 | Time: 00:00:28 | Train Loss: 1.0174 | Average Loss: 1.2552
# Epoch:33 | Iter:  140 | Time: 00:00:29 | Train Loss: 1.2026 | Average Loss: 1.2543
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.8434 | Average Loss: 1.2536
# Epoch:34 | Iter:   20 | Time: 00:00:29 | Train Loss: 1.2663 | Average Loss: 1.2525
# Epoch:34 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.7076 | Average Loss: 1.2513
# Epoch:34 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.7955 | Average Loss: 1.2501
# Epoch:34 | Iter:   80 | Time: 00:00:29 | Train Loss: 0.9949 | Average Loss: 1.2490
# Epoch:34 | Iter:  100 | Time: 00:00:29 | Train Loss: 1.0608 | Average Loss: 1.2480
# Epoch:34 | Iter:  120 | Time: 00:00:29 | Train Loss: 0.9879 | Average Loss: 1.2469
# Epoch:34 | Iter:  140 | Time: 00:00:29 | Train Loss: 1.1690 | Average Loss: 1.2459
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.8795 | Average Loss: 1.2453
# Epoch:35 | Iter:   20 | Time: 00:00:30 | Train Loss: 1.1568 | Average Loss: 1.2442
# Epoch:35 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.8160 | Average Loss: 1.2431
# Epoch:35 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.8364 | Average Loss: 1.2421
# Epoch:35 | Iter:   80 | Time: 00:00:30 | Train Loss: 0.8867 | Average Loss: 1.2411
# Epoch:35 | Iter:  100 | Time: 00:00:30 | Train Loss: 1.2090 | Average Loss: 1.2402
# Epoch:35 | Iter:  120 | Time: 00:00:30 | Train Loss: 0.8665 | Average Loss: 1.2392
# Epoch:35 | Iter:  140 | Time: 00:00:30 | Train Loss: 1.0648 | Average Loss: 1.2382
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.8291 | Average Loss: 1.2375
# Epoch:36 | Iter:   20 | Time: 00:00:30 | Train Loss: 1.2479 | Average Loss: 1.2367
# Epoch:36 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.8493 | Average Loss: 1.2356
# Epoch:36 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.9263 | Average Loss: 1.2347
# Epoch:36 | Iter:   80 | Time: 00:00:31 | Train Loss: 1.0611 | Average Loss: 1.2335
# Epoch:36 | Iter:  100 | Time: 00:00:31 | Train Loss: 1.3767 | Average Loss: 1.2326
# Epoch:36 | Iter:  120 | Time: 00:00:31 | Train Loss: 0.8177 | Average Loss: 1.2315
# Epoch:36 | Iter:  140 | Time: 00:00:31 | Train Loss: 1.1614 | Average Loss: 1.2306
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:31 | Train Loss: 1.0109 | Average Loss: 1.2301
# Epoch:37 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.9810 | Average Loss: 1.2290
# Epoch:37 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.8970 | Average Loss: 1.2281
# Epoch:37 | Iter:   60 | Time: 00:00:32 | Train Loss: 0.8850 | Average Loss: 1.2272
# Epoch:37 | Iter:   80 | Time: 00:00:32 | Train Loss: 0.9177 | Average Loss: 1.2262
# Epoch:37 | Iter:  100 | Time: 00:00:32 | Train Loss: 1.1102 | Average Loss: 1.2253
# Epoch:37 | Iter:  120 | Time: 00:00:32 | Train Loss: 0.9201 | Average Loss: 1.2243
# Epoch:37 | Iter:  140 | Time: 00:00:32 | Train Loss: 0.9749 | Average Loss: 1.2233
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.7999 | Average Loss: 1.2228
# Epoch:38 | Iter:   20 | Time: 00:00:32 | Train Loss: 1.0351 | Average Loss: 1.2218
# Epoch:38 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.8808 | Average Loss: 1.2209
# Epoch:38 | Iter:   60 | Time: 00:00:32 | Train Loss: 0.8785 | Average Loss: 1.2198
# Epoch:38 | Iter:   80 | Time: 00:00:32 | Train Loss: 0.8626 | Average Loss: 1.2189
# Epoch:38 | Iter:  100 | Time: 00:00:33 | Train Loss: 1.1481 | Average Loss: 1.2180
# Epoch:38 | Iter:  120 | Time: 00:00:33 | Train Loss: 0.8234 | Average Loss: 1.2171
# Epoch:38 | Iter:  140 | Time: 00:00:33 | Train Loss: 1.1105 | Average Loss: 1.2162
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.8791 | Average Loss: 1.2157
# Epoch:39 | Iter:   20 | Time: 00:00:33 | Train Loss: 1.0965 | Average Loss: 1.2147
# Epoch:39 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.7792 | Average Loss: 1.2137
# Epoch:39 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.7338 | Average Loss: 1.2127
# Epoch:39 | Iter:   80 | Time: 00:00:33 | Train Loss: 1.0130 | Average Loss: 1.2118
# Epoch:39 | Iter:  100 | Time: 00:00:33 | Train Loss: 1.2880 | Average Loss: 1.2109
# Epoch:39 | Iter:  120 | Time: 00:00:34 | Train Loss: 0.9910 | Average Loss: 1.2100
# Epoch:39 | Iter:  140 | Time: 00:00:34 | Train Loss: 1.1322 | Average Loss: 1.2091
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.7813 | Average Loss: 1.2087
# Epoch:40 | Iter:   20 | Time: 00:00:34 | Train Loss: 1.1797 | Average Loss: 1.2078
# Epoch:40 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.7805 | Average Loss: 1.2069
# Epoch:40 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.8908 | Average Loss: 1.2059
# Epoch:40 | Iter:   80 | Time: 00:00:34 | Train Loss: 0.8998 | Average Loss: 1.2050
# Epoch:40 | Iter:  100 | Time: 00:00:34 | Train Loss: 1.1126 | Average Loss: 1.2041
# Epoch:40 | Iter:  120 | Time: 00:00:34 | Train Loss: 1.1422 | Average Loss: 1.2033
# Epoch:40 | Iter:  140 | Time: 00:00:35 | Train Loss: 1.3530 | Average Loss: 1.2024
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.8122 | Average Loss: 1.2020
# Epoch:41 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.9715 | Average Loss: 1.2010
# Epoch:41 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.8578 | Average Loss: 1.2001
# Epoch:41 | Iter:   60 | Time: 00:00:35 | Train Loss: 0.7384 | Average Loss: 1.1993
# Epoch:41 | Iter:   80 | Time: 00:00:35 | Train Loss: 1.0370 | Average Loss: 1.1984
# Epoch:41 | Iter:  100 | Time: 00:00:35 | Train Loss: 0.9848 | Average Loss: 1.1976
# Epoch:41 | Iter:  120 | Time: 00:00:35 | Train Loss: 1.0171 | Average Loss: 1.1968
# Epoch:41 | Iter:  140 | Time: 00:00:35 | Train Loss: 1.2019 | Average Loss: 1.1960
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:36 | Train Loss: 1.1052 | Average Loss: 1.1956
# Epoch:42 | Iter:   20 | Time: 00:00:36 | Train Loss: 1.1833 | Average Loss: 1.1948
# Epoch:42 | Iter:   40 | Time: 00:00:36 | Train Loss: 0.7638 | Average Loss: 1.1940
# Epoch:42 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.8099 | Average Loss: 1.1931
# Epoch:42 | Iter:   80 | Time: 00:00:36 | Train Loss: 0.8236 | Average Loss: 1.1922
# Epoch:42 | Iter:  100 | Time: 00:00:36 | Train Loss: 1.0705 | Average Loss: 1.1914
# Epoch:42 | Iter:  120 | Time: 00:00:36 | Train Loss: 0.8691 | Average Loss: 1.1906
# Epoch:42 | Iter:  140 | Time: 00:00:36 | Train Loss: 0.9591 | Average Loss: 1.1898
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.7426 | Average Loss: 1.1894
# Epoch:43 | Iter:   20 | Time: 00:00:37 | Train Loss: 1.2436 | Average Loss: 1.1886
# Epoch:43 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.7733 | Average Loss: 1.1878
# Epoch:43 | Iter:   60 | Time: 00:00:37 | Train Loss: 0.8029 | Average Loss: 1.1870
# Epoch:43 | Iter:   80 | Time: 00:00:37 | Train Loss: 0.8932 | Average Loss: 1.1862
# Epoch:43 | Iter:  100 | Time: 00:00:37 | Train Loss: 0.9048 | Average Loss: 1.1854
# Epoch:43 | Iter:  120 | Time: 00:00:37 | Train Loss: 0.8891 | Average Loss: 1.1846
# Epoch:43 | Iter:  140 | Time: 00:00:37 | Train Loss: 1.0787 | Average Loss: 1.1838
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.8135 | Average Loss: 1.1834
# Epoch:44 | Iter:   20 | Time: 00:00:37 | Train Loss: 1.0550 | Average Loss: 1.1826
# Epoch:44 | Iter:   40 | Time: 00:00:38 | Train Loss: 0.7685 | Average Loss: 1.1817
# Epoch:44 | Iter:   60 | Time: 00:00:38 | Train Loss: 0.9193 | Average Loss: 1.1809
# Epoch:44 | Iter:   80 | Time: 00:00:38 | Train Loss: 0.9012 | Average Loss: 1.1802
# Epoch:44 | Iter:  100 | Time: 00:00:38 | Train Loss: 0.9199 | Average Loss: 1.1793
# Epoch:44 | Iter:  120 | Time: 00:00:38 | Train Loss: 0.9304 | Average Loss: 1.1787
# Epoch:44 | Iter:  140 | Time: 00:00:38 | Train Loss: 1.1428 | Average Loss: 1.1779
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:38 | Train Loss: 1.0496 | Average Loss: 1.1775
# Epoch:45 | Iter:   20 | Time: 00:00:38 | Train Loss: 1.1136 | Average Loss: 1.1767
# Epoch:45 | Iter:   40 | Time: 00:00:38 | Train Loss: 0.7159 | Average Loss: 1.1760
# Epoch:45 | Iter:   60 | Time: 00:00:39 | Train Loss: 0.7525 | Average Loss: 1.1751
# Epoch:45 | Iter:   80 | Time: 00:00:39 | Train Loss: 0.8518 | Average Loss: 1.1743
# Epoch:45 | Iter:  100 | Time: 00:00:39 | Train Loss: 0.9996 | Average Loss: 1.1734
# Epoch:45 | Iter:  120 | Time: 00:00:39 | Train Loss: 0.9970 | Average Loss: 1.1728
# Epoch:45 | Iter:  140 | Time: 00:00:39 | Train Loss: 1.0822 | Average Loss: 1.1720
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.9497 | Average Loss: 1.1717
# Epoch:46 | Iter:   20 | Time: 00:00:39 | Train Loss: 1.1143 | Average Loss: 1.1708
# Epoch:46 | Iter:   40 | Time: 00:00:39 | Train Loss: 0.6737 | Average Loss: 1.1700
# Epoch:46 | Iter:   60 | Time: 00:00:39 | Train Loss: 0.8184 | Average Loss: 1.1692
# Epoch:46 | Iter:   80 | Time: 00:00:40 | Train Loss: 0.8082 | Average Loss: 1.1684
# Epoch:46 | Iter:  100 | Time: 00:00:40 | Train Loss: 0.8837 | Average Loss: 1.1676
# Epoch:46 | Iter:  120 | Time: 00:00:40 | Train Loss: 0.8025 | Average Loss: 1.1669
# Epoch:46 | Iter:  140 | Time: 00:00:40 | Train Loss: 1.0932 | Average Loss: 1.1661
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.9310 | Average Loss: 1.1658
# Epoch:47 | Iter:   20 | Time: 00:00:40 | Train Loss: 1.1513 | Average Loss: 1.1651
# Epoch:47 | Iter:   40 | Time: 00:00:40 | Train Loss: 0.7732 | Average Loss: 1.1643
# Epoch:47 | Iter:   60 | Time: 00:00:40 | Train Loss: 0.8292 | Average Loss: 1.1635
# Epoch:47 | Iter:   80 | Time: 00:00:40 | Train Loss: 1.0350 | Average Loss: 1.1628
# Epoch:47 | Iter:  100 | Time: 00:00:40 | Train Loss: 1.0999 | Average Loss: 1.1621
# Epoch:47 | Iter:  120 | Time: 00:00:41 | Train Loss: 0.7836 | Average Loss: 1.1614
# Epoch:47 | Iter:  140 | Time: 00:00:41 | Train Loss: 1.0281 | Average Loss: 1.1606
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.8381 | Average Loss: 1.1604
# Epoch:48 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.9139 | Average Loss: 1.1595
# Epoch:48 | Iter:   40 | Time: 00:00:41 | Train Loss: 0.7653 | Average Loss: 1.1588
# Epoch:48 | Iter:   60 | Time: 00:00:41 | Train Loss: 0.8912 | Average Loss: 1.1580
# Epoch:48 | Iter:   80 | Time: 00:00:41 | Train Loss: 0.8771 | Average Loss: 1.1573
# Epoch:48 | Iter:  100 | Time: 00:00:41 | Train Loss: 1.2198 | Average Loss: 1.1566
# Epoch:48 | Iter:  120 | Time: 00:00:42 | Train Loss: 0.8180 | Average Loss: 1.1559
# Epoch:48 | Iter:  140 | Time: 00:00:42 | Train Loss: 1.0196 | Average Loss: 1.1552
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.8642 | Average Loss: 1.1548
# Epoch:49 | Iter:   20 | Time: 00:00:42 | Train Loss: 1.0126 | Average Loss: 1.1541
# Epoch:49 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.7470 | Average Loss: 1.1533
# Epoch:49 | Iter:   60 | Time: 00:00:42 | Train Loss: 0.7830 | Average Loss: 1.1526
# Epoch:49 | Iter:   80 | Time: 00:00:42 | Train Loss: 0.7794 | Average Loss: 1.1518
# Epoch:49 | Iter:  100 | Time: 00:00:42 | Train Loss: 1.0776 | Average Loss: 1.1511
# Epoch:49 | Iter:  120 | Time: 00:00:42 | Train Loss: 0.7770 | Average Loss: 1.1504
# Epoch:49 | Iter:  140 | Time: 00:00:43 | Train Loss: 1.1994 | Average Loss: 1.1498
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.8672 | Average Loss: 1.1494
# Epoch:50 | Iter:   20 | Time: 00:00:43 | Train Loss: 1.0151 | Average Loss: 1.1487
# Epoch:50 | Iter:   40 | Time: 00:00:43 | Train Loss: 0.6413 | Average Loss: 1.1479
# Epoch:50 | Iter:   60 | Time: 00:00:43 | Train Loss: 0.7732 | Average Loss: 1.1472
# Epoch:50 | Iter:   80 | Time: 00:00:43 | Train Loss: 0.9393 | Average Loss: 1.1465
# Epoch:50 | Iter:  100 | Time: 00:00:43 | Train Loss: 1.1606 | Average Loss: 1.1458
# Epoch:50 | Iter:  120 | Time: 00:00:43 | Train Loss: 0.8499 | Average Loss: 1.1451
# Epoch:50 | Iter:  140 | Time: 00:00:43 | Train Loss: 1.1775 | Average Loss: 1.1445
# Accuracy: 0.656250 | Time: 00:00:00
# TNet(
#   (features): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=212, bias=True)
#     (1): Sigmoid()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=212, out_features=16, bias=True)
#   )
# ) 1.2 - (a) network
# 154

# %% [markdown]
# **Answer**:
#
# Technique 1: Model architecture modification ( more layers and different activation functions )
#
# -> Added layer 2 of convolution and maxpooling to the first layer. Used ReLU activation here as well since using Sigmoid/Tanh activation decreases accuracy and increases computation time <br>
# -> Also, added another dense layer of 212 neurons in the classifer part of the network <br>
# -> Model converged slower (usually seen in networks with more hidden layers)
#
# Accuracy on test set: *65.6250 * % (Best - at 47th epoch)
#
# Accuracy increases/decreases: Increased compared to original network

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16,  3),
        nn.LeakyReLU(),
        nn.MaxPool2d(3, stride=3),
        nn.BatchNorm2d(16),
        nn.Conv2d(16, 16, 3), 
        nn.LeakyReLU(),
        nn.MaxPool2d(3, stride=3),
        nn.BatchNorm2d(16),
        nn.Dropout(0.5)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(576, 212), 
         nn.Sigmoid(),
         nn.Dropout(0.5),
         nn.Linear(212, 16) 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'gpu'
train_option = {'lr': 0.0005, 'epoch': 40,  'device' : device, 'loss': nn.CrossEntropyLoss}
trainModel(net, trainloader_small, train_option, testloader_small)

print(net, '1.2 - (b) network')
del net
gc.collect()
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8447 | Average Loss: 2.8447
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5654 | Average Loss: 2.7312
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5370 | Average Loss: 2.6410
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.2964 | Average Loss: 2.5719
# Accuracy: 0.372396 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.2118 | Average Loss: 2.5308
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.3164 | Average Loss: 2.4778
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.1822 | Average Loss: 2.4306
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.0119 | Average Loss: 2.3814
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0094 | Average Loss: 2.3472
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.9187 | Average Loss: 2.3018
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.9231 | Average Loss: 2.2610
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.6397 | Average Loss: 2.2225
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.6793 | Average Loss: 2.1946
# Epoch: 4 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.6907 | Average Loss: 2.1568
# Epoch: 4 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.8607 | Average Loss: 2.1233
# Epoch: 4 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.5202 | Average Loss: 2.0887
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.5391 | Average Loss: 2.0640
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4503 | Average Loss: 2.0320
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.6242 | Average Loss: 2.0029
# Epoch: 5 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.3379 | Average Loss: 1.9739
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.4137 | Average Loss: 1.9532
# Epoch: 6 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.2452 | Average Loss: 1.9265
# Epoch: 6 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.4310 | Average Loss: 1.9019
# Epoch: 6 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.3549 | Average Loss: 1.8769
# Accuracy: 0.617188 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1642 | Average Loss: 1.8590
# Epoch: 7 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.2142 | Average Loss: 1.8364
# Epoch: 7 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.4341 | Average Loss: 1.8148
# Epoch: 7 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.1838 | Average Loss: 1.7945
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1010 | Average Loss: 1.7801
# Epoch: 8 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.2093 | Average Loss: 1.7606
# Epoch: 8 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.2248 | Average Loss: 1.7419
# Epoch: 8 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.2258 | Average Loss: 1.7237
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0486 | Average Loss: 1.7110
# Epoch: 9 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.1441 | Average Loss: 1.6937
# Epoch: 9 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.2865 | Average Loss: 1.6778
# Epoch: 9 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.0137 | Average Loss: 1.6618
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1119 | Average Loss: 1.6498
# Epoch:10 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0261 | Average Loss: 1.6341
# Epoch:10 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.1929 | Average Loss: 1.6202
# Epoch:10 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.9695 | Average Loss: 1.6063
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9748 | Average Loss: 1.5962
# Epoch:11 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0207 | Average Loss: 1.5826
# Epoch:11 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.2212 | Average Loss: 1.5702
# Epoch:11 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.9694 | Average Loss: 1.5577
# Accuracy: 0.677083 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0319 | Average Loss: 1.5490
# Epoch:12 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.9611 | Average Loss: 1.5370
# Epoch:12 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.1157 | Average Loss: 1.5259
# Epoch:12 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.9060 | Average Loss: 1.5149
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8818 | Average Loss: 1.5071
# Epoch:13 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.7975 | Average Loss: 1.4961
# Epoch:13 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.1067 | Average Loss: 1.4856
# Epoch:13 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.0563 | Average Loss: 1.4754
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0197 | Average Loss: 1.4679
# Epoch:14 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.8724 | Average Loss: 1.4578
# Epoch:14 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.1729 | Average Loss: 1.4486
# Epoch:14 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.0267 | Average Loss: 1.4396
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9162 | Average Loss: 1.4330
# Epoch:15 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9995 | Average Loss: 1.4241
# Epoch:15 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.1479 | Average Loss: 1.4152
# Epoch:15 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.8695 | Average Loss: 1.4070
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8639 | Average Loss: 1.4011
# Epoch:16 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9239 | Average Loss: 1.3931
# Epoch:16 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.9225 | Average Loss: 1.3852
# Epoch:16 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.7975 | Average Loss: 1.3776
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.8322 | Average Loss: 1.3720
# Epoch:17 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.8355 | Average Loss: 1.3642
# Epoch:17 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.9964 | Average Loss: 1.3570
# Epoch:17 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.7362 | Average Loss: 1.3496
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.7945 | Average Loss: 1.3445
# Epoch:18 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.7936 | Average Loss: 1.3372
# Epoch:18 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.9907 | Average Loss: 1.3307
# Epoch:18 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.9395 | Average Loss: 1.3246
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9010 | Average Loss: 1.3200
# Epoch:19 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.7960 | Average Loss: 1.3132
# Epoch:19 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.0062 | Average Loss: 1.3070
# Epoch:19 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.7098 | Average Loss: 1.3011
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6599 | Average Loss: 1.2964
# Epoch:20 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.7398 | Average Loss: 1.2901
# Epoch:20 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.9193 | Average Loss: 1.2842
# Epoch:20 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.8399 | Average Loss: 1.2785
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.7643 | Average Loss: 1.2743
# Epoch:21 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.7117 | Average Loss: 1.2683
# Epoch:21 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.0492 | Average Loss: 1.2629
# Epoch:21 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.7195 | Average Loss: 1.2577
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.8336 | Average Loss: 1.2537
# Epoch:22 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.7499 | Average Loss: 1.2480
# Epoch:22 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.9098 | Average Loss: 1.2427
# Epoch:22 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.7318 | Average Loss: 1.2377
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6860 | Average Loss: 1.2338
# Epoch:23 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.6924 | Average Loss: 1.2287
# Epoch:23 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.8552 | Average Loss: 1.2237
# Epoch:23 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.8000 | Average Loss: 1.2186
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.7170 | Average Loss: 1.2152
# Epoch:24 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.8278 | Average Loss: 1.2103
# Epoch:24 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.8768 | Average Loss: 1.2059
# Epoch:24 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.6782 | Average Loss: 1.2013
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.7965 | Average Loss: 1.1983
# Epoch:25 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.6593 | Average Loss: 1.1934
# Epoch:25 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.9103 | Average Loss: 1.1892
# Epoch:25 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.7051 | Average Loss: 1.1853
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8395 | Average Loss: 1.1824
# Epoch:26 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.5815 | Average Loss: 1.1780
# Epoch:26 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.8785 | Average Loss: 1.1736
# Epoch:26 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.7857 | Average Loss: 1.1696
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.7531 | Average Loss: 1.1666
# Epoch:27 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.6470 | Average Loss: 1.1622
# Epoch:27 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.7580 | Average Loss: 1.1584
# Epoch:27 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.6246 | Average Loss: 1.1542
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.7098 | Average Loss: 1.1513
# Epoch:28 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.5835 | Average Loss: 1.1475
# Epoch:28 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.9383 | Average Loss: 1.1437
# Epoch:28 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.6030 | Average Loss: 1.1401
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.7757 | Average Loss: 1.1372
# Epoch:29 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.6534 | Average Loss: 1.1332
# Epoch:29 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.7913 | Average Loss: 1.1297
# Epoch:29 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.6358 | Average Loss: 1.1261
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.6791 | Average Loss: 1.1233
# Epoch:30 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.4815 | Average Loss: 1.1195
# Epoch:30 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.8024 | Average Loss: 1.1159
# Epoch:30 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.6287 | Average Loss: 1.1124
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.6501 | Average Loss: 1.1100
# Epoch:31 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.5624 | Average Loss: 1.1064
# Epoch:31 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.8257 | Average Loss: 1.1032
# Epoch:31 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.5954 | Average Loss: 1.0998
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.7102 | Average Loss: 1.0974
# Epoch:32 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.6568 | Average Loss: 1.0940
# Epoch:32 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.9218 | Average Loss: 1.0909
# Epoch:32 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.6480 | Average Loss: 1.0877
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.5524 | Average Loss: 1.0855
# Epoch:33 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.6447 | Average Loss: 1.0823
# Epoch:33 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.6381 | Average Loss: 1.0794
# Epoch:33 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.6143 | Average Loss: 1.0764
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.6314 | Average Loss: 1.0741
# Epoch:34 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.5678 | Average Loss: 1.0708
# Epoch:34 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.6907 | Average Loss: 1.0679
# Epoch:34 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.5729 | Average Loss: 1.0649
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.7229 | Average Loss: 1.0625
# Epoch:35 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.6467 | Average Loss: 1.0596
# Epoch:35 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.8192 | Average Loss: 1.0569
# Epoch:35 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.5421 | Average Loss: 1.0539
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.6411 | Average Loss: 1.0518
# Epoch:36 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.5804 | Average Loss: 1.0493
# Epoch:36 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.8740 | Average Loss: 1.0464
# Epoch:36 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.6143 | Average Loss: 1.0437
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.6834 | Average Loss: 1.0418
# Epoch:37 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.5243 | Average Loss: 1.0391
# Epoch:37 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.7814 | Average Loss: 1.0366
# Epoch:37 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.5201 | Average Loss: 1.0340
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.5774 | Average Loss: 1.0321
# Epoch:38 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.5065 | Average Loss: 1.0294
# Epoch:38 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.7237 | Average Loss: 1.0267
# Epoch:38 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.6069 | Average Loss: 1.0244
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.6891 | Average Loss: 1.0225
# Epoch:39 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.6964 | Average Loss: 1.0201
# Epoch:39 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.6475 | Average Loss: 1.0176
# Epoch:39 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.4516 | Average Loss: 1.0151
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.7011 | Average Loss: 1.0133
# Epoch:40 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.5472 | Average Loss: 1.0107
# Epoch:40 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.7079 | Average Loss: 1.0082
# Epoch:40 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.4574 | Average Loss: 1.0059
# Accuracy: 0.692708 | Time: 00:00:00
# TNet(
#   (features): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=212, bias=True)
#     (1): Sigmoid()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=212, out_features=16, bias=True)
#   )
# ) 1.2 - (b) network
# 108

# %% [markdown]
# **Answer**:
#
# Technique 2:  More layers, better activation function as per our task, entropy loss function, Batch Normalization
#
# -> Added layer 2 of convolution and maxpooling to the first layer. Used LeakyReLU activation here as well since using Sigmoid/Tanh activation decreases accuracy and increases computation time <br>
# -> Also, added another dense layer of 212 neurons in the classifer part of the network <br>
# -> Model converged slower (usually seen in networks with more hidden layers) <br>
# -> Used LeakyReLU as activation for network layers in between and Sigmoid on the output layer (recommended for multiclass classification problem) - #Ref: https://towardsdatascience.com/comparison-of-activation-functions-for-deep-neural-networks-706ac4284c8a
#
# Accuracy on test set: *69.2708%* (Best - 39th epoch)
#
# Accuracy increases/decreases: Increased compared to original network

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True, augment_rotate=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 150 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16,  3),
        nn.LeakyReLU(),
        nn.MaxPool2d(3, stride=3),
        nn.BatchNorm2d(16),
        nn.Conv2d(16, 16, 3), 
        nn.LeakyReLU(),
        nn.MaxPool2d(3, stride=3),
        nn.BatchNorm2d(16),
        nn.Dropout(0.5)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(576, 212), 
         nn.Sigmoid(),
         nn.Dropout(0.5),
         nn.Linear(212, 16) 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------

net = TNet() 
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'gpu'
train_option = {'lr': 0.0005, 'epoch': 40,  'device' : device, 'loss': nn.CrossEntropyLoss}
trainModel(net, trainloader_small, train_option, testloader_small)

print(net, '1.2 - (c) network')

del net
gc.collect()
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8135 | Average Loss: 2.8135
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6298 | Average Loss: 2.7485
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.6109 | Average Loss: 2.6810
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.4752 | Average Loss: 2.6337
# Epoch: 1 | Iter:   80 | Time: 00:00:00 | Train Loss: 2.4285 | Average Loss: 2.5900
# Epoch: 1 | Iter:  100 | Time: 00:00:00 | Train Loss: 2.2554 | Average Loss: 2.5529
# Epoch: 1 | Iter:  120 | Time: 00:00:00 | Train Loss: 2.3375 | Average Loss: 2.5162
# Epoch: 1 | Iter:  140 | Time: 00:00:00 | Train Loss: 2.4106 | Average Loss: 2.4809
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.2470 | Average Loss: 2.4664
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.2697 | Average Loss: 2.4331
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.1627 | Average Loss: 2.4024
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.0149 | Average Loss: 2.3723
# Epoch: 2 | Iter:   80 | Time: 00:00:01 | Train Loss: 2.0219 | Average Loss: 2.3454
# Epoch: 2 | Iter:  100 | Time: 00:00:01 | Train Loss: 1.9824 | Average Loss: 2.3163
# Epoch: 2 | Iter:  120 | Time: 00:00:01 | Train Loss: 1.9094 | Average Loss: 2.2872
# Epoch: 2 | Iter:  140 | Time: 00:00:01 | Train Loss: 2.0048 | Average Loss: 2.2590
# Accuracy: 0.486979 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8731 | Average Loss: 2.2462
# Epoch: 3 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.8571 | Average Loss: 2.2211
# Epoch: 3 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.8119 | Average Loss: 2.1979
# Epoch: 3 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.6691 | Average Loss: 2.1736
# Epoch: 3 | Iter:   80 | Time: 00:00:02 | Train Loss: 1.6943 | Average Loss: 2.1514
# Epoch: 3 | Iter:  100 | Time: 00:00:02 | Train Loss: 1.7275 | Average Loss: 2.1299
# Epoch: 3 | Iter:  120 | Time: 00:00:02 | Train Loss: 1.7044 | Average Loss: 2.1090
# Epoch: 3 | Iter:  140 | Time: 00:00:02 | Train Loss: 1.9078 | Average Loss: 2.0891
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.7188 | Average Loss: 2.0804
# Epoch: 4 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.8333 | Average Loss: 2.0612
# Epoch: 4 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.6937 | Average Loss: 2.0436
# Epoch: 4 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.6272 | Average Loss: 2.0268
# Epoch: 4 | Iter:   80 | Time: 00:00:03 | Train Loss: 1.5016 | Average Loss: 2.0114
# Epoch: 4 | Iter:  100 | Time: 00:00:03 | Train Loss: 1.7607 | Average Loss: 1.9962
# Epoch: 4 | Iter:  120 | Time: 00:00:03 | Train Loss: 1.5532 | Average Loss: 1.9799
# Epoch: 4 | Iter:  140 | Time: 00:00:03 | Train Loss: 1.7320 | Average Loss: 1.9649
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5666 | Average Loss: 1.9578
# Epoch: 5 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.6849 | Average Loss: 1.9438
# Epoch: 5 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.5209 | Average Loss: 1.9308
# Epoch: 5 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.4300 | Average Loss: 1.9176
# Epoch: 5 | Iter:   80 | Time: 00:00:04 | Train Loss: 1.4610 | Average Loss: 1.9061
# Epoch: 5 | Iter:  100 | Time: 00:00:04 | Train Loss: 1.6033 | Average Loss: 1.8944
# Epoch: 5 | Iter:  120 | Time: 00:00:04 | Train Loss: 1.4301 | Average Loss: 1.8827
# Epoch: 5 | Iter:  140 | Time: 00:00:04 | Train Loss: 1.6995 | Average Loss: 1.8709
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3735 | Average Loss: 1.8654
# Epoch: 6 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.4932 | Average Loss: 1.8550
# Epoch: 6 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.4985 | Average Loss: 1.8450
# Epoch: 6 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.4343 | Average Loss: 1.8345
# Epoch: 6 | Iter:   80 | Time: 00:00:05 | Train Loss: 1.3170 | Average Loss: 1.8253
# Epoch: 6 | Iter:  100 | Time: 00:00:05 | Train Loss: 1.6899 | Average Loss: 1.8165
# Epoch: 6 | Iter:  120 | Time: 00:00:05 | Train Loss: 1.4249 | Average Loss: 1.8072
# Epoch: 6 | Iter:  140 | Time: 00:00:05 | Train Loss: 1.5752 | Average Loss: 1.7978
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.3175 | Average Loss: 1.7936
# Epoch: 7 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.4795 | Average Loss: 1.7847
# Epoch: 7 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.3560 | Average Loss: 1.7764
# Epoch: 7 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.3556 | Average Loss: 1.7679
# Epoch: 7 | Iter:   80 | Time: 00:00:05 | Train Loss: 1.2327 | Average Loss: 1.7605
# Epoch: 7 | Iter:  100 | Time: 00:00:06 | Train Loss: 1.6110 | Average Loss: 1.7534
# Epoch: 7 | Iter:  120 | Time: 00:00:06 | Train Loss: 1.4071 | Average Loss: 1.7460
# Epoch: 7 | Iter:  140 | Time: 00:00:06 | Train Loss: 1.5551 | Average Loss: 1.7386
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.3625 | Average Loss: 1.7349
# Epoch: 8 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.4722 | Average Loss: 1.7278
# Epoch: 8 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.3578 | Average Loss: 1.7208
# Epoch: 8 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.2836 | Average Loss: 1.7133
# Epoch: 8 | Iter:   80 | Time: 00:00:06 | Train Loss: 1.2095 | Average Loss: 1.7072
# Epoch: 8 | Iter:  100 | Time: 00:00:06 | Train Loss: 1.5729 | Average Loss: 1.7007
# Epoch: 8 | Iter:  120 | Time: 00:00:06 | Train Loss: 1.3044 | Average Loss: 1.6943
# Epoch: 8 | Iter:  140 | Time: 00:00:07 | Train Loss: 1.4479 | Average Loss: 1.6877
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.2401 | Average Loss: 1.6842
# Epoch: 9 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.4563 | Average Loss: 1.6777
# Epoch: 9 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.2552 | Average Loss: 1.6719
# Epoch: 9 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.2349 | Average Loss: 1.6659
# Epoch: 9 | Iter:   80 | Time: 00:00:07 | Train Loss: 1.1524 | Average Loss: 1.6608
# Epoch: 9 | Iter:  100 | Time: 00:00:07 | Train Loss: 1.4548 | Average Loss: 1.6559
# Epoch: 9 | Iter:  120 | Time: 00:00:07 | Train Loss: 1.2430 | Average Loss: 1.6504
# Epoch: 9 | Iter:  140 | Time: 00:00:07 | Train Loss: 1.5006 | Average Loss: 1.6447
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.1550 | Average Loss: 1.6422
# Epoch:10 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.4298 | Average Loss: 1.6362
# Epoch:10 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.2247 | Average Loss: 1.6312
# Epoch:10 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.2176 | Average Loss: 1.6257
# Epoch:10 | Iter:   80 | Time: 00:00:08 | Train Loss: 1.0474 | Average Loss: 1.6208
# Epoch:10 | Iter:  100 | Time: 00:00:08 | Train Loss: 1.4354 | Average Loss: 1.6161
# Epoch:10 | Iter:  120 | Time: 00:00:08 | Train Loss: 1.2237 | Average Loss: 1.6112
# Epoch:10 | Iter:  140 | Time: 00:00:08 | Train Loss: 1.4409 | Average Loss: 1.6059
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.1078 | Average Loss: 1.6032
# Epoch:11 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.3784 | Average Loss: 1.5984
# Epoch:11 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.0351 | Average Loss: 1.5936
# Epoch:11 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.3019 | Average Loss: 1.5891
# Epoch:11 | Iter:   80 | Time: 00:00:09 | Train Loss: 1.0926 | Average Loss: 1.5851
# Epoch:11 | Iter:  100 | Time: 00:00:09 | Train Loss: 1.4427 | Average Loss: 1.5812
# Epoch:11 | Iter:  120 | Time: 00:00:09 | Train Loss: 1.1560 | Average Loss: 1.5768
# Epoch:11 | Iter:  140 | Time: 00:00:09 | Train Loss: 1.5085 | Average Loss: 1.5722
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.1062 | Average Loss: 1.5701
# Epoch:12 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.2536 | Average Loss: 1.5658
# Epoch:12 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.3123 | Average Loss: 1.5616
# Epoch:12 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.1954 | Average Loss: 1.5571
# Epoch:12 | Iter:   80 | Time: 00:00:10 | Train Loss: 1.1014 | Average Loss: 1.5536
# Epoch:12 | Iter:  100 | Time: 00:00:10 | Train Loss: 1.6554 | Average Loss: 1.5501
# Epoch:12 | Iter:  120 | Time: 00:00:10 | Train Loss: 1.0412 | Average Loss: 1.5466
# Epoch:12 | Iter:  140 | Time: 00:00:10 | Train Loss: 1.4755 | Average Loss: 1.5424
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.0868 | Average Loss: 1.5404
# Epoch:13 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.2672 | Average Loss: 1.5363
# Epoch:13 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.0740 | Average Loss: 1.5328
# Epoch:13 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.1150 | Average Loss: 1.5289
# Epoch:13 | Iter:   80 | Time: 00:00:11 | Train Loss: 1.0503 | Average Loss: 1.5258
# Epoch:13 | Iter:  100 | Time: 00:00:11 | Train Loss: 1.4179 | Average Loss: 1.5225
# Epoch:13 | Iter:  120 | Time: 00:00:11 | Train Loss: 1.0846 | Average Loss: 1.5190
# Epoch:13 | Iter:  140 | Time: 00:00:11 | Train Loss: 1.4216 | Average Loss: 1.5150
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.1431 | Average Loss: 1.5134
# Epoch:14 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.2424 | Average Loss: 1.5097
# Epoch:14 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.2169 | Average Loss: 1.5065
# Epoch:14 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.1300 | Average Loss: 1.5030
# Epoch:14 | Iter:   80 | Time: 00:00:12 | Train Loss: 1.0711 | Average Loss: 1.4998
# Epoch:14 | Iter:  100 | Time: 00:00:12 | Train Loss: 1.5987 | Average Loss: 1.4966
# Epoch:14 | Iter:  120 | Time: 00:00:12 | Train Loss: 1.1303 | Average Loss: 1.4938
# Epoch:14 | Iter:  140 | Time: 00:00:12 | Train Loss: 1.5035 | Average Loss: 1.4903
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.9789 | Average Loss: 1.4887
# Epoch:15 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.3189 | Average Loss: 1.4853
# Epoch:15 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.0363 | Average Loss: 1.4822
# Epoch:15 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.1455 | Average Loss: 1.4793
# Epoch:15 | Iter:   80 | Time: 00:00:12 | Train Loss: 1.0053 | Average Loss: 1.4766
# Epoch:15 | Iter:  100 | Time: 00:00:12 | Train Loss: 1.5209 | Average Loss: 1.4741
# Epoch:15 | Iter:  120 | Time: 00:00:13 | Train Loss: 0.9434 | Average Loss: 1.4712
# Epoch:15 | Iter:  140 | Time: 00:00:13 | Train Loss: 1.4374 | Average Loss: 1.4682
# Accuracy: 0.617188 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.0377 | Average Loss: 1.4667
# Epoch:16 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.2109 | Average Loss: 1.4637
# Epoch:16 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.0448 | Average Loss: 1.4607
# Epoch:16 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.1696 | Average Loss: 1.4579
# Epoch:16 | Iter:   80 | Time: 00:00:13 | Train Loss: 1.0558 | Average Loss: 1.4554
# Epoch:16 | Iter:  100 | Time: 00:00:13 | Train Loss: 1.2333 | Average Loss: 1.4527
# Epoch:16 | Iter:  120 | Time: 00:00:13 | Train Loss: 0.9565 | Average Loss: 1.4501
# Epoch:16 | Iter:  140 | Time: 00:00:14 | Train Loss: 1.4035 | Average Loss: 1.4474
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.8004 | Average Loss: 1.4459
# Epoch:17 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.1263 | Average Loss: 1.4431
# Epoch:17 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.1056 | Average Loss: 1.4405
# Epoch:17 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.1800 | Average Loss: 1.4380
# Epoch:17 | Iter:   80 | Time: 00:00:14 | Train Loss: 1.1347 | Average Loss: 1.4357
# Epoch:17 | Iter:  100 | Time: 00:00:14 | Train Loss: 1.4260 | Average Loss: 1.4332
# Epoch:17 | Iter:  120 | Time: 00:00:14 | Train Loss: 0.9503 | Average Loss: 1.4305
# Epoch:17 | Iter:  140 | Time: 00:00:14 | Train Loss: 1.3550 | Average Loss: 1.4279
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.0090 | Average Loss: 1.4267
# Epoch:18 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.2357 | Average Loss: 1.4242
# Epoch:18 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.9622 | Average Loss: 1.4219
# Epoch:18 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.1378 | Average Loss: 1.4194
# Epoch:18 | Iter:   80 | Time: 00:00:15 | Train Loss: 0.9540 | Average Loss: 1.4170
# Epoch:18 | Iter:  100 | Time: 00:00:15 | Train Loss: 1.2728 | Average Loss: 1.4147
# Epoch:18 | Iter:  120 | Time: 00:00:15 | Train Loss: 0.9168 | Average Loss: 1.4124
# Epoch:18 | Iter:  140 | Time: 00:00:15 | Train Loss: 1.2593 | Average Loss: 1.4100
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.9573 | Average Loss: 1.4089
# Epoch:19 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.1556 | Average Loss: 1.4064
# Epoch:19 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.9213 | Average Loss: 1.4040
# Epoch:19 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.9864 | Average Loss: 1.4015
# Epoch:19 | Iter:   80 | Time: 00:00:16 | Train Loss: 0.9689 | Average Loss: 1.3992
# Epoch:19 | Iter:  100 | Time: 00:00:16 | Train Loss: 1.3084 | Average Loss: 1.3971
# Epoch:19 | Iter:  120 | Time: 00:00:16 | Train Loss: 1.0437 | Average Loss: 1.3948
# Epoch:19 | Iter:  140 | Time: 00:00:16 | Train Loss: 1.2527 | Average Loss: 1.3926
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.9840 | Average Loss: 1.3915
# Epoch:20 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.2010 | Average Loss: 1.3893
# Epoch:20 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.0203 | Average Loss: 1.3871
# Epoch:20 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.9797 | Average Loss: 1.3850
# Epoch:20 | Iter:   80 | Time: 00:00:17 | Train Loss: 0.8878 | Average Loss: 1.3831
# Epoch:20 | Iter:  100 | Time: 00:00:17 | Train Loss: 1.3611 | Average Loss: 1.3812
# Epoch:20 | Iter:  120 | Time: 00:00:17 | Train Loss: 0.8550 | Average Loss: 1.3795
# Epoch:20 | Iter:  140 | Time: 00:00:17 | Train Loss: 1.3654 | Average Loss: 1.3774
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.9226 | Average Loss: 1.3764
# Epoch:21 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.1973 | Average Loss: 1.3742
# Epoch:21 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.0069 | Average Loss: 1.3723
# Epoch:21 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.9724 | Average Loss: 1.3703
# Epoch:21 | Iter:   80 | Time: 00:00:18 | Train Loss: 0.8720 | Average Loss: 1.3684
# Epoch:21 | Iter:  100 | Time: 00:00:18 | Train Loss: 1.2734 | Average Loss: 1.3667
# Epoch:21 | Iter:  120 | Time: 00:00:18 | Train Loss: 0.9911 | Average Loss: 1.3649
# Epoch:21 | Iter:  140 | Time: 00:00:18 | Train Loss: 1.1756 | Average Loss: 1.3627
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.8752 | Average Loss: 1.3616
# Epoch:22 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.1539 | Average Loss: 1.3597
# Epoch:22 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.9600 | Average Loss: 1.3579
# Epoch:22 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.9914 | Average Loss: 1.3560
# Epoch:22 | Iter:   80 | Time: 00:00:19 | Train Loss: 0.9000 | Average Loss: 1.3540
# Epoch:22 | Iter:  100 | Time: 00:00:19 | Train Loss: 1.2512 | Average Loss: 1.3522
# Epoch:22 | Iter:  120 | Time: 00:00:19 | Train Loss: 0.9288 | Average Loss: 1.3504
# Epoch:22 | Iter:  140 | Time: 00:00:19 | Train Loss: 1.3612 | Average Loss: 1.3483
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.0192 | Average Loss: 1.3472
# Epoch:23 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.1810 | Average Loss: 1.3453
# Epoch:23 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.9921 | Average Loss: 1.3436
# Epoch:23 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.0149 | Average Loss: 1.3418
# Epoch:23 | Iter:   80 | Time: 00:00:19 | Train Loss: 0.8683 | Average Loss: 1.3400
# Epoch:23 | Iter:  100 | Time: 00:00:20 | Train Loss: 1.2309 | Average Loss: 1.3384
# Epoch:23 | Iter:  120 | Time: 00:00:20 | Train Loss: 0.9005 | Average Loss: 1.3365
# Epoch:23 | Iter:  140 | Time: 00:00:20 | Train Loss: 1.2512 | Average Loss: 1.3345
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.9264 | Average Loss: 1.3336
# Epoch:24 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.1015 | Average Loss: 1.3320
# Epoch:24 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.9213 | Average Loss: 1.3303
# Epoch:24 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.9083 | Average Loss: 1.3284
# Epoch:24 | Iter:   80 | Time: 00:00:20 | Train Loss: 0.9322 | Average Loss: 1.3268
# Epoch:24 | Iter:  100 | Time: 00:00:20 | Train Loss: 1.3120 | Average Loss: 1.3253
# Epoch:24 | Iter:  120 | Time: 00:00:21 | Train Loss: 0.9507 | Average Loss: 1.3237
# Epoch:24 | Iter:  140 | Time: 00:00:21 | Train Loss: 1.2315 | Average Loss: 1.3218
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.8948 | Average Loss: 1.3209
# Epoch:25 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.1756 | Average Loss: 1.3193
# Epoch:25 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.8671 | Average Loss: 1.3178
# Epoch:25 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.9525 | Average Loss: 1.3163
# Epoch:25 | Iter:   80 | Time: 00:00:21 | Train Loss: 0.8862 | Average Loss: 1.3149
# Epoch:25 | Iter:  100 | Time: 00:00:21 | Train Loss: 1.4751 | Average Loss: 1.3132
# Epoch:25 | Iter:  120 | Time: 00:00:21 | Train Loss: 0.8023 | Average Loss: 1.3118
# Epoch:25 | Iter:  140 | Time: 00:00:22 | Train Loss: 1.2418 | Average Loss: 1.3101
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.0357 | Average Loss: 1.3093
# Epoch:26 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.1231 | Average Loss: 1.3076
# Epoch:26 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.9636 | Average Loss: 1.3062
# Epoch:26 | Iter:   60 | Time: 00:00:22 | Train Loss: 0.8880 | Average Loss: 1.3046
# Epoch:26 | Iter:   80 | Time: 00:00:22 | Train Loss: 0.8406 | Average Loss: 1.3032
# Epoch:26 | Iter:  100 | Time: 00:00:22 | Train Loss: 1.3348 | Average Loss: 1.3018
# Epoch:26 | Iter:  120 | Time: 00:00:22 | Train Loss: 1.0616 | Average Loss: 1.3001
# Epoch:26 | Iter:  140 | Time: 00:00:22 | Train Loss: 1.3636 | Average Loss: 1.2984
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.7053 | Average Loss: 1.2977
# Epoch:27 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.0054 | Average Loss: 1.2960
# Epoch:27 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.8451 | Average Loss: 1.2947
# Epoch:27 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.8813 | Average Loss: 1.2933
# Epoch:27 | Iter:   80 | Time: 00:00:23 | Train Loss: 1.0028 | Average Loss: 1.2921
# Epoch:27 | Iter:  100 | Time: 00:00:23 | Train Loss: 1.0454 | Average Loss: 1.2907
# Epoch:27 | Iter:  120 | Time: 00:00:23 | Train Loss: 0.8866 | Average Loss: 1.2893
# Epoch:27 | Iter:  140 | Time: 00:00:23 | Train Loss: 1.4274 | Average Loss: 1.2878
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.9527 | Average Loss: 1.2871
# Epoch:28 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.2261 | Average Loss: 1.2858
# Epoch:28 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.9194 | Average Loss: 1.2843
# Epoch:28 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.8156 | Average Loss: 1.2830
# Epoch:28 | Iter:   80 | Time: 00:00:24 | Train Loss: 0.9406 | Average Loss: 1.2818
# Epoch:28 | Iter:  100 | Time: 00:00:24 | Train Loss: 1.2658 | Average Loss: 1.2805
# Epoch:28 | Iter:  120 | Time: 00:00:24 | Train Loss: 0.9141 | Average Loss: 1.2794
# Epoch:28 | Iter:  140 | Time: 00:00:24 | Train Loss: 1.0962 | Average Loss: 1.2779
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:24 | Train Loss: 1.0224 | Average Loss: 1.2772
# Epoch:29 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.1168 | Average Loss: 1.2759
# Epoch:29 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.9146 | Average Loss: 1.2746
# Epoch:29 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.8787 | Average Loss: 1.2733
# Epoch:29 | Iter:   80 | Time: 00:00:25 | Train Loss: 0.7371 | Average Loss: 1.2719
# Epoch:29 | Iter:  100 | Time: 00:00:25 | Train Loss: 1.1606 | Average Loss: 1.2705
# Epoch:29 | Iter:  120 | Time: 00:00:25 | Train Loss: 0.8942 | Average Loss: 1.2692
# Epoch:29 | Iter:  140 | Time: 00:00:25 | Train Loss: 1.0841 | Average Loss: 1.2679
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.8842 | Average Loss: 1.2672
# Epoch:30 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.9808 | Average Loss: 1.2659
# Epoch:30 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.7866 | Average Loss: 1.2647
# Epoch:30 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.8144 | Average Loss: 1.2635
# Epoch:30 | Iter:   80 | Time: 00:00:26 | Train Loss: 0.9310 | Average Loss: 1.2624
# Epoch:30 | Iter:  100 | Time: 00:00:26 | Train Loss: 1.1785 | Average Loss: 1.2612
# Epoch:30 | Iter:  120 | Time: 00:00:26 | Train Loss: 0.7195 | Average Loss: 1.2600
# Epoch:30 | Iter:  140 | Time: 00:00:26 | Train Loss: 1.1142 | Average Loss: 1.2585
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.8298 | Average Loss: 1.2578
# Epoch:31 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.0983 | Average Loss: 1.2564
# Epoch:31 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.8826 | Average Loss: 1.2551
# Epoch:31 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.8022 | Average Loss: 1.2539
# Epoch:31 | Iter:   80 | Time: 00:00:26 | Train Loss: 0.9302 | Average Loss: 1.2527
# Epoch:31 | Iter:  100 | Time: 00:00:27 | Train Loss: 1.4268 | Average Loss: 1.2516
# Epoch:31 | Iter:  120 | Time: 00:00:27 | Train Loss: 0.9777 | Average Loss: 1.2504
# Epoch:31 | Iter:  140 | Time: 00:00:27 | Train Loss: 1.1972 | Average Loss: 1.2490
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.7633 | Average Loss: 1.2483
# Epoch:32 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.9572 | Average Loss: 1.2472
# Epoch:32 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.9174 | Average Loss: 1.2461
# Epoch:32 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.7178 | Average Loss: 1.2450
# Epoch:32 | Iter:   80 | Time: 00:00:27 | Train Loss: 0.8427 | Average Loss: 1.2439
# Epoch:32 | Iter:  100 | Time: 00:00:27 | Train Loss: 1.4211 | Average Loss: 1.2430
# Epoch:32 | Iter:  120 | Time: 00:00:28 | Train Loss: 0.9050 | Average Loss: 1.2420
# Epoch:32 | Iter:  140 | Time: 00:00:28 | Train Loss: 1.2342 | Average Loss: 1.2407
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.7461 | Average Loss: 1.2401
# Epoch:33 | Iter:   20 | Time: 00:00:28 | Train Loss: 1.0588 | Average Loss: 1.2389
# Epoch:33 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.8992 | Average Loss: 1.2377
# Epoch:33 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.9604 | Average Loss: 1.2367
# Epoch:33 | Iter:   80 | Time: 00:00:28 | Train Loss: 0.8150 | Average Loss: 1.2356
# Epoch:33 | Iter:  100 | Time: 00:00:28 | Train Loss: 1.1699 | Average Loss: 1.2347
# Epoch:33 | Iter:  120 | Time: 00:00:28 | Train Loss: 0.8282 | Average Loss: 1.2335
# Epoch:33 | Iter:  140 | Time: 00:00:29 | Train Loss: 1.1887 | Average Loss: 1.2322
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.7268 | Average Loss: 1.2315
# Epoch:34 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.9995 | Average Loss: 1.2302
# Epoch:34 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.9699 | Average Loss: 1.2292
# Epoch:34 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.8728 | Average Loss: 1.2281
# Epoch:34 | Iter:   80 | Time: 00:00:29 | Train Loss: 0.8416 | Average Loss: 1.2270
# Epoch:34 | Iter:  100 | Time: 00:00:29 | Train Loss: 1.2005 | Average Loss: 1.2260
# Epoch:34 | Iter:  120 | Time: 00:00:29 | Train Loss: 0.7792 | Average Loss: 1.2250
# Epoch:34 | Iter:  140 | Time: 00:00:29 | Train Loss: 1.0743 | Average Loss: 1.2239
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.7888 | Average Loss: 1.2233
# Epoch:35 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.9855 | Average Loss: 1.2223
# Epoch:35 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.8465 | Average Loss: 1.2212
# Epoch:35 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.7068 | Average Loss: 1.2200
# Epoch:35 | Iter:   80 | Time: 00:00:30 | Train Loss: 0.7578 | Average Loss: 1.2190
# Epoch:35 | Iter:  100 | Time: 00:00:30 | Train Loss: 1.2354 | Average Loss: 1.2182
# Epoch:35 | Iter:  120 | Time: 00:00:30 | Train Loss: 1.0594 | Average Loss: 1.2172
# Epoch:35 | Iter:  140 | Time: 00:00:30 | Train Loss: 1.0800 | Average Loss: 1.2159
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.8173 | Average Loss: 1.2153
# Epoch:36 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.9645 | Average Loss: 1.2142
# Epoch:36 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.9240 | Average Loss: 1.2133
# Epoch:36 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.9165 | Average Loss: 1.2122
# Epoch:36 | Iter:   80 | Time: 00:00:31 | Train Loss: 0.8671 | Average Loss: 1.2113
# Epoch:36 | Iter:  100 | Time: 00:00:31 | Train Loss: 1.2235 | Average Loss: 1.2104
# Epoch:36 | Iter:  120 | Time: 00:00:31 | Train Loss: 0.8180 | Average Loss: 1.2094
# Epoch:36 | Iter:  140 | Time: 00:00:31 | Train Loss: 1.3967 | Average Loss: 1.2084
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.9253 | Average Loss: 1.2079
# Epoch:37 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.8203 | Average Loss: 1.2068
# Epoch:37 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.7839 | Average Loss: 1.2058
# Epoch:37 | Iter:   60 | Time: 00:00:32 | Train Loss: 0.9960 | Average Loss: 1.2048
# Epoch:37 | Iter:   80 | Time: 00:00:32 | Train Loss: 0.8213 | Average Loss: 1.2040
# Epoch:37 | Iter:  100 | Time: 00:00:32 | Train Loss: 1.4847 | Average Loss: 1.2031
# Epoch:37 | Iter:  120 | Time: 00:00:32 | Train Loss: 0.8352 | Average Loss: 1.2022
# Epoch:37 | Iter:  140 | Time: 00:00:32 | Train Loss: 1.1238 | Average Loss: 1.2013
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.8456 | Average Loss: 1.2009
# Epoch:38 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.7971 | Average Loss: 1.1998
# Epoch:38 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.7763 | Average Loss: 1.1989
# Epoch:38 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.8503 | Average Loss: 1.1980
# Epoch:38 | Iter:   80 | Time: 00:00:33 | Train Loss: 0.7667 | Average Loss: 1.1971
# Epoch:38 | Iter:  100 | Time: 00:00:33 | Train Loss: 1.0013 | Average Loss: 1.1961
# Epoch:38 | Iter:  120 | Time: 00:00:33 | Train Loss: 0.8095 | Average Loss: 1.1952
# Epoch:38 | Iter:  140 | Time: 00:00:33 | Train Loss: 1.1792 | Average Loss: 1.1942
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.7341 | Average Loss: 1.1936
# Epoch:39 | Iter:   20 | Time: 00:00:33 | Train Loss: 1.0179 | Average Loss: 1.1927
# Epoch:39 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.9788 | Average Loss: 1.1919
# Epoch:39 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.8474 | Average Loss: 1.1910
# Epoch:39 | Iter:   80 | Time: 00:00:33 | Train Loss: 0.7947 | Average Loss: 1.1901
# Epoch:39 | Iter:  100 | Time: 00:00:34 | Train Loss: 1.1527 | Average Loss: 1.1892
# Epoch:39 | Iter:  120 | Time: 00:00:34 | Train Loss: 0.8790 | Average Loss: 1.1883
# Epoch:39 | Iter:  140 | Time: 00:00:34 | Train Loss: 1.2478 | Average Loss: 1.1873
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.8119 | Average Loss: 1.1868
# Epoch:40 | Iter:   20 | Time: 00:00:34 | Train Loss: 1.0477 | Average Loss: 1.1859
# Epoch:40 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.9197 | Average Loss: 1.1849
# Epoch:40 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.8682 | Average Loss: 1.1840
# Epoch:40 | Iter:   80 | Time: 00:00:34 | Train Loss: 0.7881 | Average Loss: 1.1831
# Epoch:40 | Iter:  100 | Time: 00:00:34 | Train Loss: 1.3066 | Average Loss: 1.1823
# Epoch:40 | Iter:  120 | Time: 00:00:35 | Train Loss: 0.9635 | Average Loss: 1.1815
# Epoch:40 | Iter:  140 | Time: 00:00:35 | Train Loss: 1.0807 | Average Loss: 1.1805
# Accuracy: 0.648438 | Time: 00:00:00
# TNet(
#   (features): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=212, bias=True)
#     (1): Sigmoid()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=212, out_features=16, bias=True)
#   )
# ) 1.2 - (c) network
# 108

# %% [markdown]
# **Answer**:
#
# Technique 3:  More layers, better activation function as per our task, entropy loss function, Batch Normalization, More data augmentation with rotating the images by 90 degrees
#
# -> Added layer 2 of convolution and maxpooling to the first layer. Used LeakyReLU activation here as well since using Sigmoid/Tanh activation decreases accuracy and increases computation time <br>
# -> Also, added another dense layer of 212 neurons in the classifer part of the network <br>
# -> Model converged slower (usually seen in networks with more hidden layers) <br>
# -> Used LeakyReLU as activation for network layers in between and Sigmoid on the output layer (recommended for multiclass classification problem) - #Ref: https://towardsdatascience.com/comparison-of-activation-functions-for-deep-neural-networks-706ac4284c8a <br>
# -> Augmented more data by rotating the images by 90 degrees
# Accuracy on test set: 0.703125 (Best - 39th epoch)
#
# Accuracy increases/decreases: *64.8438*% Increased compared to original network, but decreaded compared to other techniques

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 64 # training sample number per batch 

# load training dataset
# trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
#                                       augment=True, is_color=True, zero_centered=True))
trainloader_large = list(load_dataset('./data/train/', img_size, num_per_class=100, batch_size=batch_size, shuffle=True, augment=True, is_color=True, zero_centered=True)) # changed
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))
gc.collect()

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 50 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
AlexNet = torchvision.models.alexnet(pretrained=True)
# AlexNet.features[11] = nn.LeakyReLU()
AlexNet.classifier[1] = nn.Linear(9216, 2048)
AlexNet.classifier[2] = nn.LeakyReLU()
AlexNet.classifier[4] = nn.Linear(2048, 1024)
AlexNet.classifier[5] = nn.LeakyReLU()
AlexNet.classifier[6] = nn.Linear(1024,16)

print(AlexNet, '2.1 - network after modification')
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'gpu'
train_option = {'lr': 0.0001, 'epoch': 10,  'device' : device }# 'optimizer' : optim.SGD(AlexNet.parameters(), lr=0.01, momentum=0.9)}
trainModel(AlexNet, trainloader_large, train_option, testloader_large)

# del AlexNet
gc.collect()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=2048, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=1024, out_features=16, bias=True)
#   )
# ) 2.1 - network after modification
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7554 | Average Loss: 2.7554
# Epoch: 1 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.3516 | Average Loss: 2.0848
# Epoch: 1 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.9339 | Average Loss: 1.5701
# Accuracy: 0.776042 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6386 | Average Loss: 1.4120
# Epoch: 2 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.5202 | Average Loss: 1.1639
# Epoch: 2 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.5740 | Average Loss: 1.0173
# Accuracy: 0.794271 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3005 | Average Loss: 0.9610
# Epoch: 3 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3607 | Average Loss: 0.8567
# Epoch: 3 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.3463 | Average Loss: 0.7825
# Accuracy: 0.776042 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2959 | Average Loss: 0.7511
# Epoch: 4 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.2460 | Average Loss: 0.6931
# Epoch: 4 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.3155 | Average Loss: 0.6464
# Accuracy: 0.802083 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1756 | Average Loss: 0.6252
# Epoch: 5 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1622 | Average Loss: 0.5830
# Epoch: 5 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.1536 | Average Loss: 0.5503
# Accuracy: 0.804688 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1763 | Average Loss: 0.5342
# Epoch: 6 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.1588 | Average Loss: 0.5049
# Epoch: 6 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.1056 | Average Loss: 0.4777
# Accuracy: 0.789062 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0780 | Average Loss: 0.4660
# Epoch: 7 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.1051 | Average Loss: 0.4428
# Epoch: 7 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.0818 | Average Loss: 0.4214
# Accuracy: 0.791667 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0470 | Average Loss: 0.4108
# Epoch: 8 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0517 | Average Loss: 0.3922
# Epoch: 8 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.0172 | Average Loss: 0.3741
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.1146 | Average Loss: 0.3657
# Epoch: 9 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0246 | Average Loss: 0.3502
# Epoch: 9 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.0215 | Average Loss: 0.3360
# Accuracy: 0.802083 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0387 | Average Loss: 0.3293
# Epoch:10 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0360 | Average Loss: 0.3175
# Epoch:10 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0240 | Average Loss: 0.3066
# Accuracy: 0.796875 | Time: 00:00:00
# 10

# %% [markdown]
# **Answer**:
#
#
#
# Modifications:
#
# (1) which layers of AlexNet have been replaced
#
# Layers 1,2,4,5,6 of the alexnet model have been replaced
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation:  Every image is flipped around y-axis and augmented them to the dataset (same as Problem 1)
#
# Data normalization: Every image is now zero-centered as I have subtracted mean of an images from the all the pixels in an individual image (same as Problem 1)
#
# Features Layers : No change in feature layers is done
#
# Classifier Layer 1: A fully connected dense layer which has 9216 nodes as inputs and 2048 nodes as outputs + LeakyRelU activation
#
# Classifier Layer 2: A fully connected dense layer which has 2048 nodes as inputs and 1024 nodes as outputs + LeakyRelU activation
#
# Classifier Layer 3: A fully connected dense layer which has 1024 nodes as inputs and 16 nodes as outputs
#
# ...
#
# (3) the final accuracy on test set
#
# Pre-trained Alexnet model accuracy on test set after 10 epochs: *77.3438*%
#
# Modified Alexnet model accuracy on test set after 10 epochs: *81.7708*%

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------

def extract_features(model, numberOfFeatures, loader):
    features = []
    labels = []
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    for  (images, label) in loader:
      
        images, label = images.float().to(device), label.long().to(device)
        AlexNetImages = model(images)
        for index, img in enumerate(AlexNetImages):
            features.append(np.array(img[:numberOfFeatures].cpu().detach().numpy())) # Sub sampling only 1000 features
            labels.append(label[index].cpu().detach().numpy())        
    return np.array(features), np.array(labels)
    
def removeLastLayers(AlexNetNew):    
    AlexNetNew.classifier = nn.Sequential(*list(AlexNetNew.classifier.children())[:-2])
    return AlexNetNew

# AlexNetNew = torchvision.models.alexnet(pretrained=True)
AlexNetNew = AlexNet
print(AlexNetNew)
AlexNetNew = removeLastLayers(AlexNetNew) #Removes the last 2 layers of the classifier part of the network
print(AlexNetNew)
  
numberOfRequiredFeatures = 1000 # Features to extract after removing last 2 FC layers
trainFeatures, trainLabels = extract_features(AlexNetNew, numberOfRequiredFeatures, trainloader_large)
testFeatures, testLabels = extract_features(AlexNetNew, numberOfRequiredFeatures, testloader_large)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=2048, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=1024, out_features=16, bias=True)
#   )
# )
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=2048, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#   )
# )

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn import svm
from sklearn.metrics import accuracy_score

svc = svm.LinearSVC(C=0.01, max_iter = 4000)
svc.fit(trainFeatures, trainLabels)

predictions = svc.predict(testFeatures)
accuracy = accuracy_score(testLabels, predictions)*100
print(f"Accuracy of AlexNet features and one-vs-all SVM on the test set: {accuracy:.5f} ")

gc.collect()
del  svc, trainFeatures, testFeatures, trainLabels, testLabels
# Out:
# Accuracy of AlexNet features and one-vs-all SVM on the test set: 82.03125

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: *82.03125* %

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
gc.collect()

# print(torch.cuda.memory_summary(device=None, abbreviated=False))
# torch.cuda.empty_cache()

model = torchvision.models.resnet50(pretrained=True)
# print(model)
# model.relu  = nn.LeakyReLU()
model.fc = torch.nn.Sequential(
    torch.nn.Linear(
        in_features=2048,
        out_features=16                #since the last FC layer of resnet should have 16 output features
    ),
)

device = 'gpu'
train_option = {'lr': 0.0001, 'epoch': 10,  'device' : device }# 'optimizer' : optim.SGD(AlexNet.parameters(), lr=0.01, momentum=0.9)}
trainModel(model, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7445 | Average Loss: 2.7445
# Epoch: 1 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.7495 | Average Loss: 1.5750
# Epoch: 1 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.3987 | Average Loss: 1.0542
# Accuracy: 0.919271 | Time: 00:00:01
# Epoch: 2 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.2069 | Average Loss: 0.9021
# Epoch: 2 | Iter:   20 | Time: 00:00:50 | Train Loss: 0.1470 | Average Loss: 0.6895
# Epoch: 2 | Iter:   40 | Time: 00:01:04 | Train Loss: 0.0422 | Average Loss: 0.5540
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch: 3 | Iter:    0 | Time: 00:01:12 | Train Loss: 0.0263 | Average Loss: 0.5021
# Epoch: 3 | Iter:   20 | Time: 00:01:26 | Train Loss: 0.0141 | Average Loss: 0.4222
# Epoch: 3 | Iter:   40 | Time: 00:01:41 | Train Loss: 0.0129 | Average Loss: 0.3641
# Accuracy: 0.947917 | Time: 00:00:01
# Epoch: 4 | Iter:    0 | Time: 00:01:49 | Train Loss: 0.0092 | Average Loss: 0.3405
# Epoch: 4 | Iter:   20 | Time: 00:02:03 | Train Loss: 0.0047 | Average Loss: 0.3013
# Epoch: 4 | Iter:   40 | Time: 00:02:17 | Train Loss: 0.0047 | Average Loss: 0.2702
# Accuracy: 0.940104 | Time: 00:00:01
# Epoch: 5 | Iter:    0 | Time: 00:02:26 | Train Loss: 0.0060 | Average Loss: 0.2570
# Epoch: 5 | Iter:   20 | Time: 00:02:40 | Train Loss: 0.0027 | Average Loss: 0.2340
# Epoch: 5 | Iter:   40 | Time: 00:02:54 | Train Loss: 0.0032 | Average Loss: 0.2148
# Accuracy: 0.940104 | Time: 00:00:01
# Epoch: 6 | Iter:    0 | Time: 00:03:03 | Train Loss: 0.0041 | Average Loss: 0.2063
# Epoch: 6 | Iter:   20 | Time: 00:03:17 | Train Loss: 0.0020 | Average Loss: 0.1913
# Epoch: 6 | Iter:   40 | Time: 00:03:31 | Train Loss: 0.0025 | Average Loss: 0.1783
# Accuracy: 0.940104 | Time: 00:00:01
# Epoch: 7 | Iter:    0 | Time: 00:03:40 | Train Loss: 0.0032 | Average Loss: 0.1724
# Epoch: 7 | Iter:   20 | Time: 00:03:54 | Train Loss: 0.0015 | Average Loss: 0.1618
# Epoch: 7 | Iter:   40 | Time: 00:04:08 | Train Loss: 0.0020 | Average Loss: 0.1524
# Accuracy: 0.942708 | Time: 00:00:01
# Epoch: 8 | Iter:    0 | Time: 00:04:17 | Train Loss: 0.0026 | Average Loss: 0.1481
# Epoch: 8 | Iter:   20 | Time: 00:04:31 | Train Loss: 0.0013 | Average Loss: 0.1402
# Epoch: 8 | Iter:   40 | Time: 00:04:46 | Train Loss: 0.0016 | Average Loss: 0.1331
# Accuracy: 0.942708 | Time: 00:00:01
# Epoch: 9 | Iter:    0 | Time: 00:04:54 | Train Loss: 0.0021 | Average Loss: 0.1298
# Epoch: 9 | Iter:   20 | Time: 00:05:08 | Train Loss: 0.0010 | Average Loss: 0.1237
# Epoch: 9 | Iter:   40 | Time: 00:05:23 | Train Loss: 0.0013 | Average Loss: 0.1181
# Accuracy: 0.940104 | Time: 00:00:01
# Epoch:10 | Iter:    0 | Time: 00:05:31 | Train Loss: 0.0018 | Average Loss: 0.1155
# Epoch:10 | Iter:   20 | Time: 00:05:46 | Train Loss: 0.0009 | Average Loss: 0.1106
# Epoch:10 | Iter:   40 | Time: 00:06:00 | Train Loss: 0.0011 | Average Loss: 0.1062
# Accuracy: 0.940104 | Time: 00:00:01

# %% [markdown]
# **Answer**: Resnet performed better because it is more deep than Alexnet and has 50 layers on it => more paramters to tune. Also, Resnet architecture makes use of shortcut connections to solve vanishing gradients problem. Hence, any higher layer is bound to perform atleast as good as lower layers. However, Resnet needs more training time and computation power. additionally, a Resnet with full pre-activation performs better than Resnet50 ie., batch normaliztion and ReLU before addition layers.
#
# Accuracy on test set: *94.0104* %

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw4' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw4.zip" for homework4 in this structure:
# ```
# LeCun_Yann_111134567_hw4
#         |---LeCun_Yann_111134567_hw4.ipynb
#         |---LeCun_Yann_111134567_hw4.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's email: ***kgarigapati@cs.stonybrook.edu***. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have THREE days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
